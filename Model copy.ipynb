# %% [markdown]
# # Modelado

# %%
# Librerías básicas
import numpy as np
import pandas as pd
import os
import joblib

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Métodos de validación y ajuste de modelos
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, make_scorer
from scipy.stats import randint, uniform
from sklearn.preprocessing import MinMaxScaler

# Modelos de regresión
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.svm import LinearSVR
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber

# SHAP para explicación de modelos
import shap
shap.initjs()

# Importación de módulos personalizados
from modulos.data_description import *
from modulos.data_model import *
from modulos.data_visualization import *
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# ## 1. Carga del Dataset

# %%
# Cargamos el dataset internal_transformed
ruta_binario = os.path.join('data', 'internal_transformed.pkl')
internal_transformed = joblib.load(ruta_binario)

# Eliminamos la variable 'Credit_Score' para que no esté duplicada
internal_transformed.drop(columns='Credit_Score', inplace=True)

# %%
# Cargamos el dataset external_transformed
ruta_binario = os.path.join('data', 'external_transformed.pkl')
external_transformed = joblib.load(ruta_binario)

# %% [markdown]
# ### Unión ambos Dataset

# %%
# Fusión de DataFrames por PROSPECTID  
df = pd.merge(internal_transformed, external_transformed, on=['PROSPECTID'], how='inner')

# %% [markdown]
# ### División del Dataset

# %%
# Separamos variable dependiente de las independientes
X = df.drop(columns=['Credit_Score', 'PROSPECTID', 'Approved_Flag_P2', 'Approved_Flag_P3', 'Approved_Flag_P4'], inplace=False)
Y = df['Credit_Score']

# Generamos el dataset de entrenamiento y el de test
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=29, shuffle=True)

# %% [markdown]
# ## 2. Regularización (Ridge, Lasso, ElasticNet)

# %% [markdown]
# ### 2.1. Linear Regression

# %%
# Entrenamiento del modelo de regresión lineal  
linear = LinearRegression(fit_intercept=True)
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Gráfico de los coeficientes del modelo  
graficar_coeficientes(linear, X_train)

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(linear, X_test, y_test)
# Out:
#                        R^2       RMSE
# LinearRegression  0.667194  12.092869

# %% [markdown]
# ### 2.2. Ridge

# %%
# Entrenamiento del modelo Ridge con validación cruzada
modelo_ridge = RidgeCV(
    alphas=np.logspace(-3, 10, 200),
    store_cv_values=True,
    fit_intercept=False
).fit(X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:2385: FutureWarning: 'store_cv_values' is deprecated in version 1.5 and will be removed in 1.7. Use 'store_cv_results' instead.
#   warnings.warn(

# %%
# # OJO: Tiempo de computo elevado
# # Cálculo y grafico de la evolución de los coeficientes
# evaluacion_coeficientes(modelo_ridge, Ridge, X_train, y_train)

# %%
# Calculo y grafico mejor RMSE y su desviación estándar
optimo_ridge, optimo_ridge_1sd = graficar_error_cv(modelo_ridge)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\deprecation.py:110: FutureWarning: Attribute `cv_values_` is deprecated in version 1.5 and will be removed in 1.7. Use `cv_results_` instead.
#   warnings.warn(msg, category=FutureWarning)
# Mejor valor de alpha encontrado: 0.009547716114208066
# Mejor valor de alpha encontrado + 1 desviación estándar: 23.816855519761607

# %%
# Entrenamiento del modelo Ridge final con el alpha seleccionado
modelo_ridge_final = Ridge(alpha=optimo_ridge_1sd, fit_intercept=True).fit(X_train, y_train)

# Gráfico de los coeficientes del modelo  
graficar_coeficientes(modelo_ridge_final, X_train)

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(modelo_ridge_final, X_test, y_test)
# Out:
#                        R^2       RMSE
# LinearRegression  0.667194  12.092869
# Ridge             0.662578  12.176442

# %% [markdown]
# ### 2.3. Lasso

# %%
# Entrenamiento del modelo Lasso con validación cruzada
modelo_lasso = LassoCV(
    alphas=np.logspace(-8, 1, 200), 
    cv=3, 
    fit_intercept=True,
).fit(X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 
+03
#   model = cd_fast.enet_coordinate_descent(

# %%
# # OJO: Tiempo de computo elevado
# # Cálculo y grafico de la evolución de los coeficientes
# evaluacion_coeficientes(modelo_lasso, Lasso, X_train, y_train)

# %%
# Calculo y grafico mejor RMSE y su desviación estándar
optimo_lasso, optimo_lasso_1sd = graficar_error_cv(modelo_lasso)
# Out:
# Mejor valor de alpha encontrado: 9.547716114208066e-05
# Mejor valor de alpha encontrado + 1 desviación estándar: 0.021461411978584057

# %%
# Entrenamiento del modelo Lasso final con el alpha seleccionado
modelo_lasso_final = Lasso(alpha=optimo_lasso_1sd, fit_intercept=True).fit(X_train, y_train)

# Gráfico de los coeficientes del modelo  
graficar_coeficientes(modelo_lasso_final, X_train)

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(modelo_lasso_final, X_test, y_test)
# Out:
#                        R^2       RMSE
# LinearRegression  0.667194  12.092869
# Ridge             0.662578  12.176442
# Lasso             0.656402  12.287372

# %% [markdown]
# ### 2.4. Elastic Net

# %%
# ElasticNetCV - Ajuste y selección de alpha óptimo
modelo_elastic = ElasticNetCV(
    l1_ratio=[0, 0.1, 0.4, 0.7, 0.9, 0.95, 1],
    alphas=np.logspace(-5, 3, 100),
    cv=3,
    tol=0.0001,
    fit_intercept=True, 
).fit(X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5679859.625278135, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5679707.620644629, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5679524.561724576, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5679304.111854817, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5679038.644822796, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5678718.983989161, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5678334.089333291, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5677870.68234052, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5677312.796840774, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5676641.241840027, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5675832.960053764, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5674860.263268992, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5673689.922873223, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5672282.090987515, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5670589.024790158, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5668553.584086481, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5666107.470385674, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5663169.175310057, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5659641.607985231, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5655409.376398467, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5650335.708268895, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5644259.014962526, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5636989.130158865, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5628303.296532819, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5617942.0320160845, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5605605.08515455, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5590947.788052207, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5573578.233523033, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5553055.832941043, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5528891.937220481, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5500553.2991643185, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5467469.183897429, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5429042.850646397, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5384667.891544756, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5333749.49853151, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5275730.155231639, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5210118.5914674215, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5136520.224362521, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5054666.898372233, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4964443.651016634, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4865910.499214616, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4759317.76378237, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4645114.035619807, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4523946.34616015, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4396652.347611631, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4264244.388908727, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4127885.4437667965, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3988857.0653943503, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3848519.9924855363, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3708268.7024057666, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3569482.016643837, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3433472.6800185903, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3301439.489994394, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3174425.8506413195, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3053288.388906719, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2938678.410260064, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2831037.5526987165, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2730607.25718022, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2637449.956038433, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2551478.544823455, tolerance: 1136.1206500000003
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4745.290975584649, tolerance: 1110.6551840169473
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4743.07958742138, tolerance: 1110.6551840169473
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4741.240717172623, tolerance: 1110.6551840169473
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4739.71346660424, tolerance: 1110.6551840169473
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4738.444926248863, tolerance: 1110.6551840169473
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4391.366984207183, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5083.340915859677, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6074.33378914604, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6049.722487214021, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5888.046857904643, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5737.723875366151, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5485.530523078516, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5364.50316656474, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5262.941377903335, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5177.18962095771, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5104.894516334869, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5044.098490024917, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4993.088063520379, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4950.368214164861, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4914.646336698905, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4884.813542922959, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4859.924645747058, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4839.177883172408, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4821.8959931330755, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4807.508565512486, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4795.536502512172, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4785.5782582405955, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4777.297730645165, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4770.414129495621, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4764.693049949594, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4759.939072290435, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4755.98937539896, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4752.708164199255, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4749.9825769253075, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4747.719077973627, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4745.838878831826, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4744.277612512466, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4742.981183994096, tolerance: 1166.6830155885903
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.718e+06, tolerance: 1.707e+03
#   model = cd_fast.enet_coordinate_descent(

# %%
# # OJO: Tiempo de computo elevado
# # Cálculo y grafico de la evolución de los coeficientes
# evaluacion_coeficientes(modelo_elastic, ElasticNet, X_train, y_train)

# %%
# Error medio de las 10 particiones por cada valor de alpha y l1_ratio 
mean_error_cv = modelo_elastic.mse_path_.mean(axis =2)

# El resultado es un array de dimensiones (n_l1_ratio, n_alpha)
# Se convierte en un dataframe
df_resultados_cv = pd.DataFrame(
                        data   = mean_error_cv.flatten(),
                        index  = pd.MultiIndex.from_product(
                                    iterables = [modelo_elastic.l1_ratio, modelo_elastic.alphas_],
                                    names     = ['l1_ratio', 'modelo_elastic.alphas_']
                                 ),
                        columns = ["mse_cv"]
                    )

df_resultados_cv['rmse_cv'] = np.sqrt(df_resultados_cv['mse_cv'])
df_resultados_cv = df_resultados_cv.reset_index().sort_values('mse_cv', ascending = True)
df_resultados_cv
# Out:
#      l1_ratio  modelo_elastic.alphas_      mse_cv    rmse_cv
# 199       0.1                0.000010  133.213969  11.541836
# 99        0.0                0.000010  133.213969  11.541836
# 297       0.4                0.000015  133.214003  11.541837
# 198       0.1                0.000012  133.214007  11.541837
# 298       0.4                0.000012  133.214041  11.541839
# ..        ...                     ...         ...        ...
# 405       0.9              394.420606  415.598360  20.386230
# 326       0.7                7.924829  415.598360  20.386230
# 327       0.7                6.579332  415.598360  20.386230
# 328       0.7                5.462277  415.598360  20.386230
# 329       0.7                4.534879  415.598360  20.386230
#
# [700 rows x 4 columns]

# %%
# Mejor valor encontrado para cada l1_ratio
fig, ax = plt.subplots(figsize=(7, 3.84))
df_resultados_cv.groupby('l1_ratio')['rmse_cv'].min().plot(ax = ax)
ax.set_title('Evolución del error CV en función de la l1_ratio')
ax.set_xlabel('l1_ratio')
ax.set_ylabel('rmse_cv');

# %%
# Mejor valor alpha y l1_ratio_ encontrado
print(f"Mejor valor de alpha encontrado: {modelo_elastic.alpha_}")
print(f"Mejor valor de l1_ratio encontrado: {modelo_elastic.l1_ratio_}")
# Out:
# Mejor valor de alpha encontrado: 1e-05
# Mejor valor de l1_ratio encontrado: 0.1

# %%
# Ajuste del modelo ElasticNet final con el valor óptimo de alpha y l1_ratio
modelo_elastic_final = ElasticNet(alpha=modelo_elastic.alpha_, l1_ratio=modelo_elastic.l1_ratio_, fit_intercept=True).fit(X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.718e+06, tolerance: 1.707e+03
#   model = cd_fast.enet_coordinate_descent(

# %%
# Gráfico de los coeficientes del modelo  
graficar_coeficientes(modelo_elastic_final, X_train)

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(modelo_elastic_final, X_test, y_test)
# Out:
#                        R^2       RMSE
# LinearRegression  0.667194  12.092869
# ElasticNet        0.667043  12.095611
# Ridge             0.662578  12.176442
# Lasso             0.656402  12.287372

# %% [markdown]
# ## 3. Regresión Lineal

# %%
# Graficar entrenamiento del modelo
evaluar_entrenamiento(linear, X_test, y_test)
# Out:
# Evaluación del modelo: Lasso

# %% [markdown]
# Debido a que la Regresión Lineal por si misma arroja unos mejores resultados que las regularizaciones procedemos a seleccionarla para estudiar sus valores SHAP

# %%
# Crear el explicador de SHAP para el mejor modelo de regresión lineal
explainer = shap.LinearExplainer(
    model=linear, 
    masker=shap.maskers.Independent(X_train),
    feature_perturbation='interventional')

# Obtener valores SHAP en formato Explanation
shap_values = explainer(X_test)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_linear.py:95: FutureWarning: The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, maskers.Partition or maskers.Impute).
#   warnings.warn(wmsg, FutureWarning)

# %%
# Representamos todas las gráficas que hemos decidico representar de la librería SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3:
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'n_neighbors': range(1, 30)},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'))

# %%
# Obtener el mejor modelo entrenado tras la búsqueda de hiperparámetros
best_knn = grid_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(grid_search)
# Out:
# Mejores hiperparámetros encontrados:
#   Hiperparámetro  Valor
# 0    n_neighbors     15

# %%
# Obtener la evolución del error en función de k
k_values = param_grid['n_neighbors']
errors = -grid_search.cv_results_['mean_test_score']
best_k = grid_search.best_params_['n_neighbors']

# Graficar la evolución del error
plt.figure(figsize=(8, 5))
plt.plot(k_values, errors, marker='o', linestyle='dashed', color='b', label="Error MSE")
plt.axvline(best_k, linestyle="--", color="r", label=f"Mejor k = {best_k}")
plt.xlabel("Número de vecinos (k)")
plt.ylabel("Error cuadrático medio (MSE)")
plt.title("Método del codo para seleccionar k en KNN (Regresión)")
plt.xticks(k_values)
plt.legend()
plt.grid()

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_knn, X_test, y_test)
# Out:
#                           R^2       RMSE
# LinearRegression     0.667194  12.092869
# ElasticNet           0.667043  12.095611
# Ridge                0.662578  12.176442
# Lasso                0.656402  12.287372
# KNeighborsRegressor  0.490895  14.956742

# %%
# Graficar entrenamiento del modelo
evaluar_entrenamiento(best_knn, X_test, y_test)
# Out:
# Evaluación del modelo: KNeighborsRegressor

# %%
# Usar K-Means para agrupar y reducir los datos de referencia a 50 centroides
background_kmeans = shap.kmeans(X_train, 50)
background_kmeans_array = np.array(background_kmeans.data)

# Crear el explicador con el conjunto reducido
explainer = shap.KernelExplainer(
    model=best_knn.predict,
    data=background_kmeans_array,
    masker=shap.maskers.Independent(background_kmeans_array)
)

# Obtener valores SHAP para las primeras 10 muestras de prueba
shap_values = explainer(X_test.iloc[0:20, :])
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librería SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Beeswarm Plot
# Ejecutando visualización 4: Scatter Plots

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='iXLM12HE94UEFBNQMHT1D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 678.7893333333334, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue": 691.2, "simIndex": 4.0, "features": {"0": {"effect": -0.34914368311368005, "value": 0.0}, "1": {"effect": -0.18020604942012364, "value": 0.17905223175104135}, "2": {"effect": -1.0823128305497913, "value": 1.0}, "3": {"effect": -1.7658906166941801, "value": 0.0}, "4": {"effect": -0.2203357748435047, "value": 0.0}, "5": {"effect": -0.13834095752874495, "value": 0.0}, "6": {"effect": -0.11364690472786211, "value": 0.0}, "7": {"effect": 0.0, "value": 0.0}, "8": {"effect": 0.07233963787509087, "value": 0.0}, "9": {"effect": -0.1317738639412554, "value": 0.1268610025517973}, "10": {"effect": -0.1944854824570587, "value": 0.0}, "11": {"effect": 0.20477104195957962, "value": 0.15773243839286433}, "12": {"effect": 0.5072757221204126, "value": 0.6548623507611313}, "13": {"effect": 0.14182785209794943, "value": 0.0}, "14": {"effect": 1.904317571043186, "value": 0.0}, "15": {"effect": -0.03648229589985218, "value": 0.5272541507046521}, "16": {"effect": 0.29238491322425825, "value": 0.0}, "17": {"effect": 2.9584325902334814, "value": 0.9211698793217591}, "18": {"effect": 0.45964521299330746, "value": 0.6211376798922876}, "19": {"effect": -0.08292464541870201, "value": 0.7522608684733402}, "20": {"effect": 0.2476714054662506, "value": 0.7329549128453421}, "21": {"effect": -1.0672499728910134, "value": 1.0}, "22": {"effect": -0.03209214964603186, "value": 0.0}, "23": {"effect": 0.4467639827333973, "value": 0.9999999999999998}, "24": {"effect": 0.09071146216811804, "value": 0.0}, "25": {"effect": 0.1090902733351545, "value": 0.0}, "26": {"effect": -0.06641684892404504, "value": 0.0}, "27": {"effect": 0.0, "value": 0.0}, "28": {"effect": 3.6073096297997536, "value": 0.42538007674874273}, "29": {"effect": 0.0, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.011577409371556335, "value": 0.0}, "33": {"effect": 1.3943198472907916, "value": 0.0}, "34": {"effect": 0.16082502816379327, "value": 0.0}, "35": {"effect": 0.0, "value": 0.0}, "36": {"effect": 0.0, "value": 0.0}, "37": {"effect": 0.0, "value": 0.0}, "38": {"effect": 0.0, "value": 0.0}, "39": {"effect": 0.0, "value": 0.0}, "40": {"effect": 0.0, "value": 0.0}, "41": {"effect": 0.056643491600842914, "value": 1.0}, "42": {"effect": -0.06161698576812864, "value": 0.0}, "43": {"effect": -0.3552381514953133, "value": 0.0}, "44": {"effect": -0.5872330176094112, "value": 0.0}, "45": {"effect": 0.0, "value": 0.0}, "46": {"effect": 0.1091864436489902, "value": 0.0}, "47": {"effect": 1.5753427980444223, "value": 0.0}, "48": {"effect": 0.0, "value": 0.0}, "49": {"effect": 0.30928987560212623, "value": 0.0}, "50": {"effect": 0.1777803862612955, "value": 1.0}, "51": {"effect": 0.15816333 ...

# %% [markdown]
# ## 5. Modelos basados en árboles de decisión

# %% [markdown]
# ### 5.1. Árbol de decisión

# %%
# Definir el rango de hiperparámetros
param_dist = {
    'criterion': ['squared_error', 'friedman_mse'],
    'max_depth': range(8, 17, 1),
    'min_samples_split': [10, 15, 20],
    'max_features': ['sqrt', 'log2']
}

# Crear el modelo de árbol de decisión para regresión
tree = DecisionTreeRegressor()

# Configurar GridSearchCV con validación cruzada de 3 folds
random_search = RandomizedSearchCV(
    tree, 
    param_distributions=param_dist,  
    n_iter=50,
    cv=5,
    scoring='neg_mean_squared_error',  
    n_jobs=-1,  
    random_state=29,  
    verbose=1  
)

# Ajustar el modelo en los datos de entrenamiento
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'friedman_mse'],
#                                         'max_depth': range(8, 17),
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_split': [10, 15, 20]},
#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
# Obtener el mejor modelo
best_tree = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#       Hiperparámetro          Valor
# 0  min_samples_split             20
# 1       max_features           sqrt
# 2          max_depth             14
# 3          criterion  squared_error

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_tree, X_test, y_test)
# Out:
#                             R^2       RMSE
# LinearRegression       0.667194  12.092869
# ElasticNet             0.667043  12.095611
# Ridge                  0.662578  12.176442
# Lasso                  0.656402  12.287372
# DecisionTreeRegressor  0.561362  13.883110
# KNeighborsRegressor    0.490895  14.956742

# %% [markdown]
# ### 5.2. Random Forest

# %%
# Definir el modelo
forest = RandomForestRegressor()

# Definir la parrilla de hiperparámetros
param_dist = {
    'n_estimators': randint(100, 1000),
    'criterion': ['squared_error', 'friedman_mse'],
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'max_features': ['sqrt', 'log2']
}

# Configurar la búsqueda aleatoria
random_search = RandomizedSearchCV(
    estimator=forest,
    param_distributions=param_dist,
    n_iter=50,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=29,
    n_jobs=-1
)

# Ejecutar la búsqueda
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'friedman_mse'],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7BBC29F50>,
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7BBDD0550>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7BBC291D0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7BBC7AF90>},
#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# Obtener el mejor modelo
best_forest = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#       Hiperparámetro          Valor
# 0          criterion  squared_error
# 1          max_depth              9
# 2       max_features           sqrt
# 3   min_samples_leaf             15
# 4  min_samples_split              5
# 5       n_estimators            366

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_forest, X_test, y_test)
# Out:
#                             R^2       RMSE
# RandomForestRegressor  0.673625  11.975448
# LinearRegression       0.667194  12.092869
# ElasticNet             0.667043  12.095611
# Ridge                  0.662578  12.176442
# Lasso                  0.656402  12.287372
# DecisionTreeRegressor  0.561362  13.883110
# KNeighborsRegressor    0.490895  14.956742

# %% [markdown]
# ### 5.3. XGBoost

# %%
# Definir el modelo
xgb = xgb.XGBRegressor(tree_method='hist', objective='reg:squarederror')

# Definir la parrilla de hiperparámetros
param_dist = {
    'n_estimators': randint(200, 1200),
    'learning_rate': uniform(0.005, 0.3),
    'max_depth': randint(4, 15),
    'min_child_weight': randint(1, 15),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 15),
    'reg_alpha': uniform(0, 2),
    'reg_lambda': uniform(0, 2)
}

# Configurar la búsqueda aleatoria
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=50,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=29,
    n_jobs=-1
)

# Ejecutar la búsqueda
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001B7BBE34B10>,
#                                         'reg_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001B7BBBF4B10>,
#                                         'reg_lambda': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001B7BBBF75D0>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001B7BB796090>},
#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# Obtener el mejor modelo
best_xgb = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#      Hiperparámetro       Valor
# 0  colsample_bytree    0.872759
# 1             gamma    8.778080
# 2     learning_rate    0.033239
# 3         max_depth    6.000000
# 4  min_child_weight    7.000000
# 5      n_estimators  743.000000
# 6         reg_alpha    1.482022
# 7        reg_lambda    1.177261
# 8         subsample    0.796580

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_xgb, X_test, y_test)
# Out:
#                             R^2       RMSE
# XGBRegressor           0.791125   9.580257
# RandomForestRegressor  0.673625  11.975448
# LinearRegression       0.667194  12.092869
# ElasticNet             0.667043  12.095611
# Ridge                  0.662578  12.176442
# Lasso                  0.656402  12.287372
# DecisionTreeRegressor  0.561362  13.883110
# KNeighborsRegressor    0.490895  14.956742

# %% [markdown]
# ### 5.4. Mejor modelo de Arbol (XGB)

# %%
# Graficar entrenamiento del modelo
evaluar_entrenamiento(best_xgb, X_test, y_test)
# Out:
# Evaluación del modelo: XGBRegressor

# %% [markdown]
# Como el modelo basado en árboles que mejor predicción ha arrojado es el entrenado con XGBoost, escogemos a este para analizar sus valores SHAP.

# %%
# Crear el explicador de SHAP para el mejor modelo de árbol de decisión
explainer = shap.TreeExplainer(
    model=best_xgb,
    data=X_train,
    model_output='raw',
    feature_perturbation='interventional')

# Obtener los valores SHAP para todo el conjunto de prueba
shap_values = explainer(X_test)
# Out:
# 100%|===================| 10230/10268 [04:40<00:01]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librería SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Beeswarm Plot
# Ejecutando visualización 4: Scatter Plots

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='iHGINW9ZQMU86W0IP19VR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 677.0211328643385, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue":

#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# Obtener el mejor modelo
best_svr = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#   Hiperparámetro       Valor
# 0              C   10.052213
# 1        epsilon    0.324214
# 2       max_iter  816.000000

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_svr, X_test, y_test)
# Out:
#                             R^2       RMSE
# XGBRegressor           0.791125   9.580257
# RandomForestRegressor  0.673625  11.975448
# LinearRegression       0.667194  12.092869
# ElasticNet             0.667043  12.095611
# Ridge                  0.662578  12.176442
# Lasso                  0.656402  12.287372
# LinearSVR              0.654892  12.314343
# DecisionTreeRegressor  0.561362  13.883110
# KNeighborsRegressor    0.490895  14.956742

# %%
# Graficar entrenamiento del modelo
evaluar_entrenamiento(best_svr, X_test, y_test)
# Out:
# Evaluación del modelo: LinearSVR

# %%
# Crear el explicador SHAP para SVR
explainer = shap.KernelExplainer(
    model=best_svr.predict,  
    data=X_train[:100],
    link="identity" 
)

# Calcular valores SHAP para un subconjunto de datos de prueba
shap_values = explainer(X_test[:20])
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librería SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Beeswarm Plot
# Ejecutando visualización 4: Scatter Plots

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='iOD5ZKCIQV0VQ9MED6KY6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 679.0182061349811, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue": 705.5398516255863, "simIndex": 11.0, "features": {"0": {"effect": -3.5143162733082227, "value": 0.0}, "1": {"effect": 1.070147829378534, "value": 0.17905223175104135}, "2": {"effect": 5.930266648826337, "value": 1.0}, "3": {"effect": -9.256821525913105, "value": 0.0}, "4": {"effect": 0.0445720296962697, "value": 0.0}, "5": {"effect": -0.549441678988063, "value": 0.0}, "6": {"effect": -0.5406292854749412, "value": 0.0}, "7": {"effect": -0.9063115717408529, "value": 0.0}, "8": {"effect": -0.6813764355313614, "value": 0.0}, "9": {"effect": 0.03709200170830968, "value": 0.1268610025517973}, "10": {"effect": 0.20035588330354973, "value": 0.0}, "11": {"effect": 0.3236272731189426, "value": 0.15773243839286433}, "12": {"effect": 6.834276090695735, "value": 0.6548623507611313}, "13": {"effect": 0.31356749132402567, "value": 0.0}, "14": {"effect": -4.1028044154760455, "value": 0.0}, "15": {"effect": -0.16247111245059614, "value": 0.5272541507046521}, "16": {"effect": -0.08915463012913924, "value": 0.0}, "17": {"effect": 8.263683741936784, "value": 0.9211698793217591}, "18": {"effect": 0.6307818720819159, "value": 0.6211376798922876}, "19": {"effect": 0.4266529827801969, "value": 0.7522608684733402}, "20": {"effect": 0.16382305292603952, "value": 0.7329549128453421}, "21": {"effect": 5.9302666488263345, "value": 1.0}, "22": {"effect": 0.4202306642794892, "value": 0.0}, "23": {"effect": -0.03207647763496465, "value": 0.9999999999999998}, "24": {"effect": 0.024538040278577537, "value": 0.0}, "25": {"effect": 0.14306915278654028, "value": 0.0}, "26": {"effect": 0.10822601303740716, "value": 0.0}, "27": {"effect": 0.24350385252628856, "value": 0.0}, "28": {"effect": 7.185554091608751, "value": 0.42538007674874273}, "29": {"effect": 0.02085969337072334, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.7875010235182166, "value": 0.0}, "33": {"effect": 2.397713504239008, "value": 0.0}, "34": {"effect": -0.040944741995423285, "value": 0.0}, "35": {"effect": -0.020019717359166224, "value": 0.0}, "36": {"effect": -0.008492444800307378, "value": 0.0}, "37": {"effect": -0.006958497522576063, "value": 0.0}, "38": {"effect": -0.01104896102290322, "value": 0.0}, "39": {"effect": 0.02292046632860917, "value": 0.0}, "40": {"effect": 0.014557918190532634, "value": 0.0}, "41": {"effect": 0.08673829982337286, "value": 1.0}, "42": {"effect": 0.1053168694377609, "value": 0.0}, "43": {"effect": 0.509065816901383, "value": 0.0}, "44": {"effect": -0.06988770687932024, "value": 0.0}, "45": {"effect": 0.561795858856951, "value": 0.0}, "46": {"effect": -0.10459002363919688, "value": 0.0}, "47": {"effect": 0.4143610015020849, "value": 0.0}, "48": { ...

# %% [markdown]
# ## 7. Red Neuronal Multicapa

# %%
# Transformamos la variable objetivo a una escala 0-1
scaler = MinMaxScaler()
Y_scaled = scaler.fit_transform(df[['Credit_Score']])

# Generamos el dataset de entrenamiento y el de test
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(
    X, Y_scaled, test_size=0.20, random_state=29, shuffle=True)

# %%
# Función para el ajuste de la tasa de aprendizaje
def lr_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.95

# Crear el modelo
dense = Sequential()

# Capa de entrada con normalización y activación LeakyReLU
dense.add(Input(shape=(X_train_scaled.shape[1],)))
dense.add(Dense(256, kernel_regularizer=l2(0.0005)))
dense.add(BatchNormalization()) 
dense.add(LeakyReLU(negative_slope=0.01))

# Capas ocultas con activación LeakyReLU y BatchNormalization
dense.add(Dense(128, kernel_regularizer=l2(0.0005)))
dense.add(BatchNormalization())
dense.add(LeakyReLU(negative_slope=0.01))

dense.add(Dense(64, kernel_regularizer=l2(0.0005)))
dense.add(BatchNormalization())
dense.add(LeakyReLU(negative_slope=0.01))

# Nueva capa oculta con 64 neuronas
dense.add(Dense(32, kernel_regularizer=l2(0.0005)))
dense.add(BatchNormalization())
dense.add(LeakyReLU(negative_slope=0.01))

# Dropout para evitar sobreajuste
dense.add(Dropout(0.2))

# Capa de salida (regresión)
dense.add(Dense(1, activation="linear"))

# Compilar el modelo con el optimizador Adam
optimizer = Adam(learning_rate=0.0005)

dense.compile(optimizer=optimizer, loss=Huber(), metrics=["mean_squared_error"])


# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_callback = LearningRateScheduler(lr_scheduler)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

# Entrenamiento del modelo
history = dense.fit(X_train_scaled, y_train_scaled, validation_data=(X_test_scaled, y_test_scaled), epochs=100, 
                    batch_size=256, callbacks=[early_stopping, lr_callback, reduce_lr])
# Out:
# Epoch 1/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3702 - mean_squared_error: 0.3835 - val_loss: 0.2539 - val_mean_squared_error: 0.1390 - learning_rate: 5.0000e-04
# Epoch 2/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2388 - mean_squared_error: 0.1166 - val_loss: 0.1885 - val_mean_squared_error: 0.0395 - learning_rate: 5.0000e-04
# Epoch 3/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1941 - mean_squared_error: 0.0594 - val_loss: 0.1571 - val_mean_squared_error: 0.0125 - learning_rate: 5.0000e-04
# Epoch 4/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1624 - mean_squared_error: 0.0325 - val_loss: 0.1359 - val_mean_squared_error: 0.0079 - learning_rate: 5.0000e-04
# Epoch 5/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1379 - mean_squared_error: 0.0212 - val_loss: 0.1156 - val_mean_squared_error: 0.0045 - learning_rate: 5.0000e-04
# Epoch 6/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1161 - mean_squared_error: 0.0145 - val_loss: 0.0980 - val_mean_squared_error: 0.0047 - learning_rate: 5.0000e-04
# Epoch 7/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0967 - mean_squared_error: 0.0105 - val_loss: 0.0809 - val_mean_squared_error: 0.0031 - learning_rate: 5.0000e-04
# Epoch 8/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0798 - mean_squared_error: 0.0084 - val_loss: 0.0661 - val_mean_squared_error: 0.0025 - learning_rate: 5.0000e-04
# Epoch 9/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0648 - mean_squared_error: 0.0065 - val_loss: 0.0533 - val_mean_squared_error: 0.0024 - learning_rate: 5.0000e-04
# Epoch 10/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0520 - mean_squared_error: 0.0055 - val_loss: 0.0424 - val_mean_squared_error: 0.0021 - learning_rate: 5.0000e-04
# Epoch 11/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0414 - mean_squared_error: 0.0045 - val_loss: 0.0336 - val_mean_squared_error: 0.0017 - learning_rate: 4.7500e-04
# Epoch 12/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0329 - mean_squared_error: 0.0038 - val_loss: 0.0269 - val_mean_squared_error: 0.0018 - learning_rate: 4.5125e-04
# Epoch 13/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0263 - mean_squared_error: 0.0035 - val_loss: 0.0215 - val_mean_squared_error: 0.0017 - learning_rate: 4.2869e-04
# Epoch 14/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0211 - mean_squared_error: 0.0031 - val_loss: 0.0172 - val_mean_squared_error: 0.0017 - learning_rate: 4.0725e-04
# Epoch 15/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0169 - mean_squared_error: 0.0028 - val_loss: 0.0139 - val_mean_squared_error: 0.0016 - learning_rate: 3.8689e-04
# Epoch 16/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0137 - mean_squared_error: 0.0026 - val_loss: 0.0114 - val_mean_squared_error: 0.0018 - learning_rate: 3.6755e-04
# Epoch 17/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0111 - mean_squared_error: 0.0023 - val_loss: 0.0094 - val_mean_squared_error: 0.0019 - learning_rate: 3.4917e-04
# Epoch 18/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0091 - mean_squared_error: 0.0022 - val_loss: 0.0077 - val_mean_squared_error: 0.0017 - learning_rate: 3.3171e-04
# Epoch 19/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0075 - mean_squared_error: 0.0020 - val_loss: 0.0064 - val_mean_squared_error: 0.0016 - learning_rate: 3.1512e-04
# Epoch 20/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - mean_squared_error: 0.0020 - val_loss: 0.0053 - val_mean_squared_error: 0.0015 - learning_rate: 2.9937e-04
# Epoch 21/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0053 - mean_squared_error: 0.0018 - val_loss: 0.0045 - val_mean_squared_error: 0.0015 - learning_rate: 2.8440e-04
# Epoch 22/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0045 - mean_squared_error: 0.0018 - val_loss: 0.0038 - val_mean_squared_error: 0.0014 - learning_rate: 2.7018e-04
# Epoch 23/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0038 - mean_squared_error: 0.0017 - val_loss: 0.0033 - val_mean_squared_error: 0.0015 - learning_rate: 2.5667e-04
# Epoch 24/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - mean_squared_error: 0.0016 - val_loss: 0.0029 - val_mean_squared_error: 0.0015 - learning_rate: 2.4384e-04
# Epoch 25/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - mean_squared_error: 0.0015 - val_loss: 0.0025 - val_mean_squared_error: 0.0014 - learning_rate: 2.3165e-04
# Epoch 26/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0025 - mean_squared_error: 0.0015 - val_loss: 0.0022 - val_mean_squared_error: 0.0013 - learning_rate: 2.2006e-04
# Epoch 27/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0022 - mean_squared_error: 0.0014 - val_loss: 0.0019 - val_mean_squared_error: 0.0012 - learning_rate: 2.0906e-04
# Epoch 28/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0019 - mean_squared_error: 0.0013 - val_loss: 0.0018 - val_mean_squared_error: 0.0013 - learning_rate: 1.9861e-04
# Epoch 29/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - mean_squared_error: 0.0013 - val_loss: 0.0017 - val_mean_squared_error: 0.0015 - learning_rate: 1.8868e-04
# Epoch 30/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0013 - val_loss: 0.0015 - val_mean_squared_error: 0.0013 - learning_rate: 1.7924e-04
# Epoch 31/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0014 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_squared_error: 0.0012 - learning_rate: 1.7028e-04
# Epoch 32/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0013 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0011 - learning_rate: 1.6177e-04
# Epoch 33/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - learning_rate: 1.5368e-04
# Epoch 34/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - learning_rate: 1.4599e-04
# Epoch 35/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0010 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0011 - learning_rate: 1.3869e-04
# Epoch 36/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.8969e-04 - mean_squared_error: 0.0011 - val_loss: 9.7696e-04 - val_mean_squared_error: 0.0011 - learning_rate: 1.3176e-04
# Epoch 37/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3893e-04 - mean_squared_error: 0.0011 - val_loss: 9.9232e-04 - val_mean_squared_error: 0.0012 - learning_rate: 1.2517e-04
# Epoch 38/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.0710e-04 - mean_squared_error: 0.0011 - val_loss: 9.3094e-04 - val_mean_squared_error: 0.0012 - learning_rate: 1.1891e-04
# Epoch 39/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.5694e-04 - mean_squared_error: 0.0010 - val_loss: 8.7890e-04 - val_mean_squared_error: 0.0011 - learning_rate: 1.1297e-04
# Epoch 40/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.9950e-04 - mean_squared_error: 9.7621e-04 - val_loss: 8.3712e-04 - val_mean_squared_error: 0.0011 - learning_rate: 1.0732e-04
# Epoch 41/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6784e-04 - mean_squared_error: 9.6302e-04 - val_loss: 7.8582e-04 - val_mean_squared_error: 0.0010 - learning_rate: 1.0195e-04
# Epoch 42/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.4120e-04 - mean_squared_error: 9.5527e-04 - val_loss: 7.5979e-04 - val_mean_squared_error: 0.0010 - learning_rate: 9.6856e-05
# Epoch 43/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.0783e-04 - mean_squared_error: 9.2791e-04 - val_loss: 6.9958e-04 - val_mean_squared_error: 9.3835e-04 - learning_rate: 9.2013e-05
# Epoch 44/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9284e-04 - mean_squared_error: 9.3220e-04 - val_loss: 6.6595e-04 - val_mean_squared_error: 9.0490e-04 - learning_rate: 8.7412e-05
# Epoch 45/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6326e-04 - mean_squared_error: 9.0573e-04 - val_loss: 6.9854e-04 - val_mean_squared_error: 9.9691e-04 - learning_rate: 8.3042e-05
# Epoch 46/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2685e-04 - mean_squared_error: 8.6083e-04 - val_loss: 6.4720e-04 - val_mean_squared_error: 9.2148e-04 - learning_rate: 7.8890e-05
# Epoch 47/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.2481e-04 - mean_squared_error: 8.8247e-04 - val_loss: 6.5290e-04 - val_mean_squared_error: 9.5513e-04 - learning_rate: 7.4945e-05
# Epoch 48/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.0497e-04 - mean_squared_error: 8.6469e-04 - val_loss: 6.2616e-04 - val_mean_squared_error: 9.2295e-04 - learning_rate: 7.1198e-05
# Epoch 49/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.9023e-04 - mean_squared_error: 8.5535e-04 - val_loss: 6.1236e-04 - val_mean_squared_error: 9.1455e-04 - learning_rate: 6.7638e-05
# Epoch 50/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.6670e-04 - mean_squared_error: 8.2513e-04 - val_loss: 5.8938e-04 - val_mean_squared_error: 8.7812e-04 - learning_rate: 3.2128e-05
# Epoch 51/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.5618e-04 - mean_squared_error: 8.1305e-04 - val_loss: 6.0882e-04 - val_mean_squared_error: 9.2475e-04 - learning_rate: 3.0522e-05
# Epoch 52/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4464e-04 - mean_squared_error: 7.9803e-04 - val_loss: 5.7748e-04 - val_mean_squared_error: 8.6938e-04 - learning_rate: 2.8996e-05
# Epoch 53/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.2830e-04 - mean_squared_error: 7.7288e-04 - val_loss: 5.7028e-04 - val_mean_squared_error: 8.6264e-04 - learning_rate: 2.7546e-05
# Epoch 54/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.2350e-04 - mean_squared_error: 7.7022e-04 - val_loss: 5.7470e-04 - val_mean_squared_error: 8.7743e-04 - learning_rate: 2.6168e-05
# Epoch 55/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.2063e-04 - mean_squared_error: 7.7037e-04 - val_loss: 5.6064e-04 - val_mean_squared_error: 8.5284e-04 - learning_rate: 1.2430e-05
# Epoch 56/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.1222e-04 - mean_squared_error: 7.5680e-04 - val_loss: 5.6340e-04 - val_mean_squared_error: 8.6194e-04 - learning_rate: 1.1809e-05
# Epoch 57/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.0318e-04 - mean_squared_error: 7.4200e-04 - val_loss: 5.5552e-04 - val_mean_squared_error: 8.4892e-04 - learning_rate: 1.1218e-05
# Epoch 58/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.0933e-04 - mean_squared_error: 7.5707e-04 - val_loss: 5.5187e-04 - val_mean_squared_error: 8.4436e-04 - learning_rate: 1.0657e-05
# Epoch 59/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.0025e-04 - mean_squared_error: 7.4170e-04 - val_loss: 5.5239e-04 - val_mean_squared_error: 8.4772e-04 - learning_rate: 1.0124e-05
# Epoch 60/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.8982e-04 - mean_squared_error: 7.2352e-04 - val_loss: 5.5224e-04 - val_mean_squared_error: 8.5056e-04 - learning_rate: 9.6181e-06
# Epoch 61/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.8962e-04 - mean_squared_error: 7.2568e-04 - val_loss: 5.5628e-04 - val_mean_squared_error: 8.6111e-04 - learning_rate: 9.1372e-06
# Epoch 62/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.0003e-04 - mean_squared_error: 7.4909e-04 - val_loss: 5.5016e-04 - val_mean_squared_error: 8.5094e-04 - learning_rate: 8.6804e-06
# Epoch 63/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.9264e-04 - mean_squared_error: 7.3682e-04 - val_loss: 5.4359e-04 - val_mean_squared_error: 8.4006e-04 - learning_rate: 8.2463e-06
# Epoch 64/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.8784e-04 - mean_squared_error: 7.2916e-04 - val_loss: 5.4587e-04 - val_mean_squared_error: 8.4713e-04 - learning_rate: 7.8340e-06
# Epoch 65/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.9128e-04 - mean_squared_error: 7.3853e-04 - val_loss: 5.4037e-04 - val_mean_squared_error: 8.3831e-04 - learning_rate: 7.4423e-06
# Epoch 66/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.7208e-04 - mean_squared_error: 7.0214e-04 - val_loss: 5.4471e-04 - val_mean_squared_error: 8.4891e-04 - learning_rate: 7.0702e-06
# Epoch 67/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.8084e-04 - mean_squared_error: 7.2166e-04 - val_loss: 5.4095e-04 - val_mean_squared_error: 8.4374e-04 - learning_rate: 6.7167e-06
# Epoch 68/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.8538e-04 - mean_squared_error: 7.3290e-04 - val_loss: 5.4490e-04 - val_mean_squared_error: 8.5343e-04 - learning_rate: 6.3809e-06
# Epoch 69/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.7495e-04 - mean_squared_error: 7.1396e-04 - val_loss: 5.3995e-04 - val_mean_squared_error: 8.4535e-04 - learning_rate: 6.0618e-06
# Epoch 70/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.6932e-04 - mean_squared_error: 7.0463e-04 - val_loss: 5.4253e-04 - val_mean_squared_error: 8.5247e-04 - learning_rate: 5.7587e-06
# Epoch 71/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.7506e-04 - mean_squared_error: 7.1799e-04 - val_loss: 5.4230e-04 - val_mean_squared_error: 8.5331e-04 - learning_rate: 5.4708e-06
# Epoch 72/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.6639e-04 - mean_squared_error: 7.0207e-04 - val_loss: 5.3850e-04 - val_mean_squared_error: 8.4761e-04 - learning_rate: 5.1972e-06
# Epoch 73/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.7330e-04 - mean_squared_error: 7.1771e-04 - val_loss: 5.3768e-04 - val_mean_squared_error: 8.4752e-04 - learning_rate: 4.9374e-06
# Epoch 74/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.6659e-04 - mean_squared_error: 7.0581e-04 - val_loss: 5.3654e-04 - val_mean_squared_error: 8.4684e-04 - learning_rate: 4.6905e-06
# Epoch 75/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.6835e-04 - mean_squared_error: 7.1099e-04 - val_loss: 5.3583e-04 - val_mean_squared_error: 8.4685e-04 - learning_rate: 4.4560e-06
# Epoch 76/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.5607e-04 - mean_squared_error: 6.8779e-04 - val_loss: 5.3646e-04 - val_mean_squared_error: 8.4978e-04 - learning_rate: 4.2332e-06
# Epoch 77/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.5942e-04 - mean_squared_error: 6.9593e-04 - val_loss: 5.3526e-04 - val_mean_squared_error: 8.4824e-04 - learning_rate: 4.0215e-06
# Epoch 78/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.6533e-04 - mean_squared_error: 7.0875e-04 - val_loss: 5.3538e-04 - val_mean_squared_error: 8.4993e-04 - learning_rate: 3.8205e-06
# Epoch 79/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.6537e-04 - mean_squared_error: 7.1023e-04 - val_loss: 5.3382e-04 - val_mean_squared_error: 8.4800e-04 - learning_rate: 3.6294e-06
# Epoch 80/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.5913e-04 - mean_squared_error: 6.9888e-04 - val_loss: 5.3466e-04 - val_mean_squared_error: 8.5084e-04 - learning_rate: 3.4480e-06
# Epoch 81/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.5952e-04 - mean_squared_error: 7.0081e-04 - val_loss: 5.3618e-04 - val_mean_squared_error: 8.5482e-04 - learning_rate: 3.2756e-06
# Epoch 82/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.5464e-04 - mean_squared_error: 6.9202e-04 - val_loss: 5.3293e-04 - val_mean_squared_error: 8.4942e-04 - learning_rate: 3.1118e-06
# Epoch 83/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.5103e-04 - mean_squared_error: 6.8593e-04 - val_loss: 5.3496e-04 - val_mean_squared_error: 8.5442e-04 - learning_rate: 2.9562e-06
# Epoch 84/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4877e-04 - mean_squared_error: 6.8224e-04 - val_loss: 5.3194e-04 - val_mean_squared_error: 8.4921e-04 - learning_rate: 2.8084e-06
# Epoch 85/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.5304e-04 - mean_squared_error: 6.9171e-04 - val_loss: 5.3242e-04 - val_mean_squared_error: 8.5107e-04 - learning_rate: 2.6680e-06
# Epoch 86/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.4631e-04 - mean_squared_error: 6.7910e-04 - val_loss: 5.3233e-04 - val_mean_squared_error: 8.5178e-04 - learning_rate: 2.5346e-06
# Epoch 87/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.5199e-04 - mean_squared_error: 6.9129e-04 - val_loss: 5.3313e-04 - val_mean_squared_error: 8.5420e-04 - learning_rate: 2.4078e-06
# Epoch 88/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.5302e-04 - mean_squared_error: 6.9409e-04 - val_loss: 5.3215e-04 - val_mean_squared_error: 8.5293e-04 - learning_rate: 2.2874e-06
# Epoch 89/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.5055e-04 - mean_squared_error: 6.8986e-04 - val_loss: 5.3082e-04 - val_mean_squared_error: 8.5086e-04 - learning_rate: 2.1731e-06
# Epoch 90/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.4651e-04 - mean_squared_error: 6.8246e-04 - val_loss: 5.3249e-04 - val_mean_squared_error: 8.5504e-04 - learning_rate: 2.0644e-06
# Epoch 91/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.4085e-04 - mean_squared_error: 6.7189e-04 - val_loss: 5.3297e-04 - val_mean_squared_error: 8.5660e-04 - learning_rate: 1.9612e-06
# Epoch 92/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.4719e-04 - mean_squared_error: 6.8519e-04 - val_loss: 5.3158e-04 - val_mean_squared_error: 8.5431e-04 - learning_rate: 1.8631e-06
# Epoch 93/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.3747e-04 - mean_squared_error: 6.6628e-04 - val_loss: 5.3097e-04 - val_mean_squared_error: 8.5373e-04 - learning_rate: 1.7700e-06
# Epoch 94/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.4959e-04 - mean_squared_error: 6.9108e-04 - val_loss: 5.3113e-04 - val_mean_squared_error: 8.5450e-04 - learning_rate: 1.6815e-06
# Epoch 95/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4711e-04 - mean_squared_error: 6.8662e-04 - val_loss: 5.3099e-04 - val_mean_squared_error: 8.5471e-04 - learning_rate: 1.5974e-06
# Epoch 96/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.3893e-04 - mean_squared_error: 6.7075e-04 - val_loss: 5.3041e-04 - val_mean_squared_error: 8.5405e-04 - learning_rate: 1.5175e-06
# Epoch 97/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4249e-04 - mean_squared_error: 6.7829e-04 - val_loss: 5.3016e-04 - val_mean_squared_error: 8.5392e-04 - learning_rate: 1.4417e-06
# Epoch 98/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.3576e-04 - mean_squared_error: 6.6520e-04 - val_loss: 5.3056e-04 - val_mean_squared_error: 8.5526e-04 - learning_rate: 1.3696e-06
# Epoch 99/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.4078e-04 - mean_squared_error: 6.7577e-04 - val_loss: 5.3055e-04 - val_mean_squared_error: 8.5553e-04 - learning_rate: 1.3011e-06
# Epoch 100/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.3957e-04 - mean_squared_error: 6.7371e-04 - val_loss: 5.3021e-04 - val_mean_squared_error: 8.5534e-04 - learning_rate: 1.2360e-06

# %%
# Graficar los valores de error absoluto medio durante el entrenamiento
plt.figure(figsize=(13,6))
plt.plot(history.history['mean_squared_error'], label='Entrenamiento (MSE)')
plt.plot(history.history['val_mean_squared_error'], label='Validación (MSE)')
plt.title('Error Cuadrático Medio (MSE) durante el entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(dense, X_test_scaled, y_test_scaled)
# Out:
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#                  R^2      RMSE
# Sequential  0.772699  0.029222

# %%
y_pred_train = dense.predict(X_train_scaled)
y_pred_test = dense.predict(X_test_scaled)

plt.figure(figsize=(8,5))
x_vals = np.linspace(0, 1, 100)
plt.plot(x_vals, x_vals, color="black", linestyle="dashed", label="Referencia (y=x)")
plt.scatter(y_train_scaled, y_pred_train, label="Entrenamiento", alpha=0.6)
plt.scatter(y_test_scaled, y_pred_test, label="Validación", alpha=0.6, marker="x")
plt.xlabel("Valor Real")
plt.ylabel("Predicción")
plt.legend()
plt.title("Comparación entre Predicciones y Valores Reales")
plt.show()
# Out:
# 1284/1284 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/