# %% [markdown]
# # Modelado

# %% [markdown]
# EXTRATEGIA QUE SE HA DECIDIDO SEGUIR:

# %%
# Librerías básicas
import numpy as np
import pandas as pd
import os
import joblib

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Métodos de validación y ajuste de modelos
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, make_scorer
from scipy.stats import randint, uniform


# Modelos de regresión
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.svm import LinearSVR
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Input, LeakyReLU
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from tensorflow.keras.callbacks import LearningRateScheduler

# SHAP para explicación de modelos
import shap
shap.initjs()

# Importación de módulos personalizados
from modulos.data_description import *
from modulos.data_model import *
from modulos.data_visualization import *
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# ## 1. Carga del Dataset

# %%
# Cargamos el dataset internal_transformed
ruta_binario = os.path.join('data', 'internal_transformed.pkl')
internal_transformed = joblib.load(ruta_binario)

# Eliminamos la variable 'Credit_Score' para que no esté duplicada
internal_transformed.drop(columns='Credit_Score', inplace=True)

# %%
# Cargamos el dataset external_transformed
ruta_binario = os.path.join('data', 'external_transformed.pkl')
external_transformed = joblib.load(ruta_binario)

# %% [markdown]
# ### Unión ambos Dataset

# %%
# Fusión de DataFrames por PROSPECTID  
df = pd.merge(internal_transformed, external_transformed, on=['PROSPECTID'], how='inner')

# %% [markdown]
# ### División del Dataset

# %%
# Separamos variable dependiente de las independientes
X = df.drop(columns=['Credit_Score', 'PROSPECTID','Approved_Flag_P2','Approved_Flag_P3','Approved_Flag_P4'], inplace=False)
Y = df['Credit_Score']

# Generamos el dataset de entrenamiento y el de test
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.20, random_state=29, shuffle=True)

# %% [markdown]
# ## 2. Regularización (Ridge, Lasso, ElasticNet)

# %% [markdown]
# ### 2.1. Linear Regression

# %%
# Entrenamiento del modelo de regresión lineal  
linear = LinearRegression(fit_intercept=False)
linear.fit(X_train, y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
# Gráfico de los coeficientes del modelo  
graficar_coeficientes(linear, X_train)

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(linear, X_test, y_test)
# Out:
#                        R^2      RMSE
# LinearRegression  0.639927  0.036779

# %% [markdown]
# ### 2.2. Ridge

# %%
# Entrenamiento del modelo Ridge con validación cruzada
modelo_ridge = RidgeCV(
    alphas=np.logspace(-3, 10, 200),
    store_cv_values=True,
    fit_intercept=False
).fit(X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_ridge.py:2385: FutureWarning: 'store_cv_values' is deprecated in version 1.5 and will be removed in 1.7. Use 'store_cv_results' instead.
#   warnings.warn(

# %%
# Cálculo y grafico de la evolución de los coeficientes
evaluacion_coeficientes(modelo_ridge, Ridge, X_train, y_train)

# %%
# Calculo y grafico mejor RMSE y su desviación estándar
optimo_ridge = graficar_error_cv(modelo_ridge)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\deprecation.py:110: FutureWarning: Attribute `cv_values_` is deprecated in version 1.5 and will be removed in 1.7. Use `cv_results_` instead.
#   warnings.warn(msg, category=FutureWarning)
# Mejor valor de alpha encontrado: 0.19338917504552322
# Mejor valor de alpha encontrado + 1 desviación estándar: 24094.03560239527

# %%
# Entrenamiento del modelo Ridge final con el alpha seleccionado
modelo_ridge_final = Ridge(alpha=optimo_ridge, fit_intercept=False).fit(X_train, y_train)

# Gráfico de los coeficientes del modelo  
graficar_coeficientes(modelo_ridge_final, X_train)

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(modelo_ridge_final, X_test, y_test)
# Out:
#                        R^2      RMSE
# LinearRegression  0.639927  0.036779
# Ridge             0.639911  0.036780

# %% [markdown]
# ### 2.3. Lasso

# %%
# Entrenamiento del modelo Lasso con validación cruzada
modelo_lasso = LassoCV(
    alphas=np.logspace(-10, 3, 100), 
    cv=3, 
    fit_intercept=False,
).fit(X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.755e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Cálculo y grafico de la evolución de los coeficientes
evaluacion_coeficientes(modelo_lasso, Lasso, X_train, y_train)

# %%
# Calculo y grafico mejor RMSE y su desviación estándar
optimo_lasso = graficar_error_cv(modelo_lasso)
# Out:
# Mejor valor de alpha encontrado: 1.592282793341094e-06
# Mejor valor de alpha encontrado + 1 desviación estándar: 0.0006734150657750829

# %%
# Entrenamiento del modelo Lasso final con el alpha seleccionado
modelo_lasso_final = Lasso(alpha=optimo_lasso, fit_intercept=False).fit(X_train, y_train)

# Gráfico de los coeficientes del modelo  
graficar_coeficientes(modelo_lasso_final, X_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.111e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(modelo_lasso_final, X_test, y_test)
# Out:
#                        R^2      RMSE
# LinearRegression  0.770402  0.029369
# Ridge             0.770399  0.029369
# Lasso             0.770340  0.029373

# %%
NO CORRER MÁS

# %% [markdown]
# ### 2.4. Elastic Net

# %%
# ElasticNetCV - Ajuste y selección de alpha óptimo
modelo_elastic = ElasticNetCV(
    l1_ratio=[0, 0.1, 0.4, 0.5, 0.7, 0.9, 0.99],
    alphas=np.logspace(-8, 3, 100),
    cv=3,
    fit_intercept=False,  
).fit(X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5224.101283604304, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5215.371019806365, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5204.139498347275, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5189.706411711885, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5171.1860478743365, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5147.465148101284, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5117.155745346695, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5078.545632832052, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5029.551869071044, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4967.686878890847, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4890.052443704271, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4793.38387825045, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4674.173578675669, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4528.906666445348, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4354.435995547676, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4148.501863749924, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3910.357341798691, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3641.395549951878, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3345.609633647509, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3029.687704187458, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2702.5955146812084, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2374.6414314265107, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2056.204877143389, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1756.4470729688712, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1482.3308298068605, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1238.1493051152274, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1025.5768759812065, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 844.104634083896, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 691.6619972862458, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 565.248040076043, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 461.4609285523916, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 376.8812580318425, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308.31305424359255, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 252.91039776707132, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 208.22366572699238, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172.19537273204173, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 143.12805097825083, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.63928522736252, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100.61336775602365, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85.15515825104845, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72.54915041691308, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.22494812028702, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.729066006478114, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.70216395808045, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.86053224830055, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.980783495893505, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.88706803473596, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.440476876338842, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.530485261429412, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.06830288872748, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.981908821808783, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.212452408205994, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.71165240448181, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.439838501826078, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.36434749688554, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.458098179453478, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.698296229081977, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.06531989724343, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.541864333115976, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.112383975291447, tolerance: 1.0508547989124857
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.806123266389976, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.804563142870261, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.803354930881556, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.802419297246145, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.801694774773505, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.801133746180275, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.800699327795003, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.800362952869982, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.800102497686053, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799900829292012, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799744680349301, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799623777233743, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799530164759569, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799457683048605, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.79940156254287, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799358110121869, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799324466256063, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799298416918388, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: UserWarning: Coordinate descent without L1 regularization may lead to unexpected results and is discouraged. Set l1_ratio > 0 to add L1 regularization.
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.799278247822569, tolerance: 1.0503872482131256
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.140e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Cálculo y grafico de la evolución de los coeficientes
evaluacion_coeficientes(modelo_elastic, ElasticNet, X_train, y_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.562e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.561e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.561e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.560e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.559e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.558e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.557e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.555e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.552e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.549e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.545e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.539e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.532e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.523e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.512e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.497e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.478e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.454e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.424e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.385e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.336e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.276e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.201e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.109e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.998e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.711e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.305e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.350e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.798e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.701e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.678e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.675e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.753e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.968e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.185e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.375e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.381e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.600e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.718e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.750e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.628e+00, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Cálculo del error medio cuadrático (MSE) y desviación estándar en validación cruzada
mse_cv = modelo_elastic.mse_path_.mean(axis=2)
mse_sd = modelo_elastic.mse_path_.std(axis=2)

# Cálculo del error cuadrático medio (RMSE) y su desviación estándar
rmse_cv, rmse_sd = np.sqrt(mse_cv), np.sqrt(mse_sd)

# Selección de los índices óptimos para el mejor valor de L1 y alpha
best_l1_idx, best_alpha_idx = np.unravel_index(np.argmin(rmse_cv), rmse_cv.shape)

# Selección del mejor valor de alpha y el valor de alpha + 1 desviación estándar
optimo_elastic, optimo_elastic_1sd = seleccionar_alpha_optimo(
    rmse_cv[best_l1_idx, :], rmse_sd[best_l1_idx, :], modelo_elastic.alphas_)

# %%
# Error medio de las 10 particiones por cada valor de alpha y l1_ratio
mean_error_cv = modelo_elastic.mse_path_.mean(axis=2)

# El resultado es un array de dimensiones (n_l1_ratio, n_alpha), se convierte en un dataframe
df_resultados_cv = pd.DataFrame(
                        data   = mean_error_cv.flatten(),
                        index  = pd.MultiIndex.from_product(
                                    iterables = [modelo_elastic.l1_ratio, modelo_elastic.alphas_],
                                    names     = ['l1_ratio', 'modelo_elastic.alphas_']
                                 ),
                        columns = ["mse_cv"]
                    )

# Cálculo del RMSE a partir del MSE
df_resultados_cv['rmse_cv'] = np.sqrt(df_resultados_cv['mse_cv'])

# Ordenación de los resultados por MSE en orden ascendente
df_resultados_cv = df_resultados_cv.reset_index().sort_values('mse_cv', ascending=True)

# Visualización del dataframe con los resultados
df_resultados_cv
# Out:
#      l1_ratio  modelo_elastic.alphas_    mse_cv   rmse_cv
# 579      0.90                0.000002  0.000765  0.027667
# 679      0.99                0.000002  0.000765  0.027667
# 680      0.99                0.000001  0.000765  0.027667
# 580      0.90                0.000001  0.000765  0.027667
# 478      0.70                0.000002  0.000765  0.027667
# ..        ...                     ...       ...       ...
# 402      0.70              599.484250  0.383779  0.619499
# 403      0.70              464.158883  0.383779  0.619499
# 404      0.70              359.381366  0.383779  0.619499
# 405      0.70              278.255940  0.383779  0.619499
# 326      0.50                1.291550  0.383779  0.619499
#
# [700 rows x 4 columns]

# %%
# Impresión del mejor valor de alpha y l1_ratio encontrados
print(f"Mejor valor de alpha encontrado: {modelo_elastic.alpha_}")
print(f"Mejor valor de l1_ratio encontrado: {modelo_elastic.l1_ratio_}")
# Out:
# Mejor valor de alpha encontrado: 1.6681005372000591e-06
# Mejor valor de l1_ratio encontrado: 0.9

# %%
# Mejor valor encontrado para cada l1_ratio
fig, ax = plt.subplots(figsize=(7, 3.84))

# Graficar el mejor valor de RMSE para cada l1_ratio
df_resultados_cv.groupby('l1_ratio')['rmse_cv'].min().plot(ax=ax)

# Configuración del gráfico
ax.set_title('Evolución del error CV en función de la l1_ratio')
ax.set_xlabel('l1_ratio')
ax.set_ylabel('rmse_cv');

# %%
# Ajuste del modelo ElasticNet final con el valor óptimo de alpha
modelo_elastic_final = ElasticNet(alpha=optimo_elastic, fit_intercept=False).fit(X_train, y_train)

# Gráfico de los coeficientes del modelo  
graficar_coeficientes(modelo_elastic_final, X_train)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.336e+01, tolerance: 1.576e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(modelo_elastic_final, X_test, y_test)
# Out:
#                        R^2      RMSE
# LinearRegression  0.770402  0.029369
# Ridge             0.770399  0.029369
# ElasticNet        0.770373  0.029371
# Lasso             0.770340  0.029373

# %% [markdown]
# ## 3. Regresión Lineal

# %% [markdown]
# Debido a que la Regresión Lineal por si misma arroja unos mejores resultados que las regularizaciones procedemos a seleccionarla para estudiar sus valores SHAP

# %%
# Crear el explicador de SHAP para el mejor modelo de regresión lineal
explainer = shap.LinearExplainer(
    model=linear, 
    masker=shap.maskers.Independent(X_train),
    feature_perturbation='interventional')

# Obtener valores SHAP en formato Explanation
shap_values = explainer(X_test)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_linear.py:95: FutureWarning: The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, maskers.Partition or maskers.Impute).
#   warnings.warn(wmsg, FutureWarning)

# %%
# Representamos todas las gráficas que hemos decidico representar de la librerís SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Force Plot
# Error en la visualización 3: matplotlib = True is not yet supported for force plots with multiple samples!
# Ejecutando visualización 4: Beeswarm Plot
# Ejecutando visualización 5: Scatter Plots

# %% [markdown]
# **shap.force_plot** no admite múltiples muestras con matplotlib, por lo que podría ser necesario recorrer varias observaciones individualmente

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='iYAJB66GP9WZX11CI73YN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6070964770169125, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue": 0.6963357479861124, "simIndex": 41.0, "features": {"0": {"effect": -0.014536253112955758, "value": 0.0}, "1": {"effect": 0.006092490760183664, "value": 0.17905223175104135}, "2": {"effect": 0.09293056333524632, "value": 1.0}, "3": {"effect": -0.17299599278956168, "value": 0.0}, "4": {"effect": -0.0004940816054819601, "value": 0.0}, "5": {"effect": -0.0010879585211138988, "value": 0.0}, "6": {"effect": -0.002142641029076356, "value": 0.0}, "7": {"effect": -0.0013911567483275442, "value": 0.0}, "8": {"effect": -0.0015939848529293392, "value": 0.0}, "9": {"effect": -0.0010856199133880081, "value": 0.1268610025517973}, "10": {"effect": -0.0024759056528408352, "value": 0.0}, "11": {"effect": 0.0007548127165880663, "value": 0.15773243839286433}, "12": {"effect": 0.01777165207027299, "value": 0.6548623507611313}, "13": {"effect": 0.0012416187460591054, "value": 0.0}, "14": {"effect": -0.012451757706353258, "value": 0.0}, "15": {"effect": -5.7742366795823134e-06, "value": 0.5272541507046521}, "16": {"effect": -0.001234869728712593, "value": 0.0}, "17": {"effect": 0.027061191018041966, "value": 0.9211698793217591}, "18": {"effect": 0.002171019386011163, "value": 0.6211376798922876}, "19": {"effect": 0.0035423539872040783, "value": 0.7522608684733402}, "20": {"effect": 0.0012120230901873788, "value": 0.7329549128453421}, "21": {"effect": 0.09293056333526693, "value": 1.0}, "22": {"effect": 0.0017070489193069518, "value": 0.0}, "23": {"effect": -0.004317906315109088, "value": 0.9999999999999998}, "24": {"effect": -0.00014299255778475143, "value": 0.0}, "25": {"effect": -2.383888177689396e-05, "value": 0.0}, "26": {"effect": 0.0006532090707382004, "value": 0.0}, "27": {"effect": 0.0012323419322553988, "value": 0.0}, "28": {"effect": 0.02680407715921525, "value": 0.42538007674874273}, "29": {"effect": 6.18679897947401e-06, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.005360350846889128, "value": 0.0}, "33": {"effect": 0.009761242973782336, "value": 0.0}, "34": {"effect": -0.0003959222736608359, "value": 0.0}, "35": {"effect": -0.00022928880123281148, "value": 0.0}, "36": {"effect": -1.6685688430179146e-05, "value": 0.0}, "37": {"effect": 1.7196550483938936e-05, "value": 0.0}, "38": {"effect": 0.0, "value": 0.0}, "39": {"effect": -2.1295286122817312e-05, "value": 0.0}, "40": {"effect": 6.600856784158809e-05, "value": 0.0}, "41": {"effect": 0.000318000058679965, "value": 1.0}, "42": {"effect": 0.0010151627825394237, "value": 0.0}, "43": {"effect": 0.001589875774681882, "value": 0.0}, "44": {"effect": 3.465955959657818e-06, "value": 0.0}, "45": {"effect": 0.000821032967209577, "value": 0.0}, "46": {"effect": -0.001464123 ...

# %% [markdown]
# ## 4. K-Nearest Neighbours (KNN)

# %%
# Definir el rango de valores de k a evaluar
param_grid = {'n_neighbors': range(1, 30)}

# Crear el modelo kNN para regresión
knn = KNeighborsRegressor()

# Configurar GridSearchCV con validación cruzada de 5 folds
grid_search = GridSearchCV(
    knn, 
    param_grid, 
    cv=5, 
    scoring=make_scorer(mean_squared_error, greater_is_better=False),
    n_jobs=-1
)

# Ajustar el modelo en los datos de entrenamiento
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'n_neighbors': range(1, 30)},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'))

# %%
# Obtener el mejor modelo entrenado tras la búsqueda de hiperparámetros
best_knn = grid_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(grid_search)
# Out:
# Mejores hiperparámetros encontrados:
#   Hiperparámetro  Valor
# 0    n_neighbors     15

# %%
# Obtener la evolución del error en función de k
k_values = param_grid['n_neighbors']
errors = -grid_search.cv_results_['mean_test_score']
best_k = grid_search.best_params_['n_neighbors']

# Graficar la evolución del error
plt.figure(figsize=(8, 5))
plt.plot(k_values, errors, marker='o', linestyle='dashed', color='b', label="Error MSE")
plt.axvline(best_k, linestyle="--", color="r", label=f"Mejor k = {best_k}")
plt.xlabel("Número de vecinos (k)")
plt.ylabel("Error cuadrático medio (MSE)")
plt.title("Método del codo para seleccionar k en KNN (Regresión)")
plt.xticks(k_values)
plt.legend()
plt.grid()

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_knn, X_test, y_test)
# Out:
#                           R^2      RMSE
# LinearRegression     0.639927  0.036779
# Ridge                0.639911  0.036780
# KNeighborsRegressor  0.490895  0.043733

# %%
# Usar K-Means para agrupar y reducir los datos de referencia a 50 centroides
background_kmeans = shap.kmeans(X_train, 50)
background_kmeans_array = np.array(background_kmeans.data)

# Crear el explicador con el conjunto reducido
explainer = shap.KernelExplainer(
    model=best_knn.predict,
    data=background_kmeans_array,
    masker=shap.maskers.Independent(background_kmeans_array)
)

# Obtener valores SHAP para las primeras 10 muestras de prueba
shap_values = explainer(X_test.iloc[0:20, :])
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librerís SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Force Plot
# Error en la visualización 3: matplotlib = True is not yet supported for force plots with multiple samples!
# Ejecutando visualización 4: Beeswarm Plot
# Ejecutando visualización 5: Scatter Plots

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='iVVPYPEH4M7RKO5TA3GKG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.61341910331384, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue": 0.6497076023391812, "simIndex": 4.0, "features": {"0": {"effect": -0.0011844439049079843, "value": 0.0}, "1": {"effect": -0.0006612771735164141, "value": 0.17905223175104135}, "2": {"effect": -0.003398137194641079, "value": 1.0}, "3": {"effect": -0.004952715493777079, "value": 0.0}, "4": {"effect": -0.0004836146731662571, "value": 0.0}, "5": {"effect": -0.0006122217053791696, "value": 0.0}, "6": {"effect": 0.0002075152014367565, "value": 0.0}, "7": {"effect": 0.0, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": -0.00053612696208118, "value": 0.1268610025517973}, "10": {"effect": -0.000947568860048472, "value": 0.0}, "11": {"effect": 0.00020551815649010616, "value": 0.15773243839286433}, "12": {"effect": 0.001333145607547589, "value": 0.6548623507611313}, "13": {"effect": 0.0005528321103570862, "value": 0.0}, "14": {"effect": 0.0062155826684952105, "value": 0.0}, "15": {"effect": 0.0, "value": 0.5272541507046521}, "16": {"effect": 0.0003354679548397321, "value": 0.0}, "17": {"effect": 0.008891189248967543, "value": 0.9211698793217591}, "18": {"effect": 0.0010206918678239453, "value": 0.6211376798922876}, "19": {"effect": -0.00033450214834379203, "value": 0.7522608684733402}, "20": {"effect": 0.0007395874771237286, "value": 0.7329549128453421}, "21": {"effect": -0.0031568008640367735, "value": 1.0}, "22": {"effect": -0.00039081659242070586, "value": 0.0}, "23": {"effect": 0.0013902140665242489, "value": 0.9999999999999998}, "24": {"effect": -0.0002689982514435154, "value": 0.0}, "25": {"effect": 0.0009972209771349802, "value": 0.0}, "26": {"effect": -0.00018416873119049917, "value": 0.0}, "27": {"effect": 0.00012856750856186098, "value": 0.0}, "28": {"effect": 0.010464286368331894, "value": 0.42538007674874273}, "29": {"effect": 0.0, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.0, "value": 0.0}, "33": {"effect": 0.0040319210230449175, "value": 0.0}, "34": {"effect": 0.000923563738166338, "value": 0.0}, "35": {"effect": 0.00029574667397600104, "value": 0.0}, "36": {"effect": 0.0, "value": 0.0}, "37": {"effect": 0.0, "value": 0.0}, "38": {"effect": 0.0, "value": 0.0}, "39": {"effect": 0.0, "value": 0.0}, "40": {"effect": 0.0, "value": 0.0}, "41": {"effect": 0.0001232569275091671, "value": 1.0}, "42": {"effect": 0.0, "value": 0.0}, "43": {"effect": -0.001085217776935153, "value": 0.0}, "44": {"effect": -0.0017028637841665904, "value": 0.0}, "45": {"effect": 0.0, "value": 0.0}, "46": {"effect": 0.0006538966435589314, "value": 0.0}, "47": {"effect": 0.004622940088533753, "value": 0.0}, "48": {"effect": 0.0, "value": 0.0}, "49": {"effect": 0.0013304164721771575, "value": 0.0}, "50": {"effect": 0. ...

# %% [markdown]
# ## 5. Modelos basados en árboles de decisión

# %% [markdown]
# ### 5.1. Árbol de decisión

# %%
# Definir el rango de hiperparámetros
param_dist = {
    'criterion': ['squared_error', 'friedman_mse'],
    'max_depth': range(8, 17, 1),
    'min_samples_split': [10, 15, 20],
    'max_features': ['sqrt', 'log2']
}

# Crear el modelo de árbol de decisión para regresión
tree = DecisionTreeRegressor()

# Configurar GridSearchCV con validación cruzada de 3 folds
random_search = RandomizedSearchCV(
    tree, 
    param_distributions=param_dist,  
    n_iter=50,
    cv=5,
    scoring='neg_mean_squared_error',  
    n_jobs=-1,  
    random_state=29,  
    verbose=1  
)

# Ajustar el modelo en los datos de entrenamiento
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'friedman_mse'],
#                                         'max_depth': range(8, 17),
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_split': [10, 15, 20]},
#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
# Obtener el mejor modelo
best_tree = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#       Hiperparámetro         Valor
# 0  min_samples_split            10
# 1       max_features          sqrt
# 2          max_depth            14
# 3          criterion  friedman_mse

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_tree, X_test, y_test)
# Out:
#                             R^2      RMSE
# LinearRegression       0.639927  0.036779
# Ridge                  0.639911  0.036780
# KNeighborsRegressor    0.490895  0.043733
# DecisionTreeRegressor  0.490267  0.043760

# %% [markdown]
# ### 5.2. Random Forest

# %%
# Definir el modelo
forest = RandomForestRegressor()

# Definir la parrilla de hiperparámetros
param_dist = {
    'n_estimators': randint(100, 1000),
    'criterion': ['squared_error', 'friedman_mse'],
    'max_depth': randint(3, 10),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'max_features': ['sqrt', 'log2']
}

# Configurar la búsqueda aleatoria
random_search = RandomizedSearchCV(
    estimator=forest,
    param_distributions=param_dist,
    n_iter=50,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=29,
    n_jobs=-1
)

# Ejecutar la búsqueda
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'friedman_mse'],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000151F96C6FD0>,
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000151F96C7E10>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000151F96C6650>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000151F7609790>},
#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# Obtener el mejor modelo
best_forest = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#       Hiperparámetro          Valor
# 0          criterion  squared_error
# 1          max_depth              9
# 2       max_features           sqrt
# 3   min_samples_leaf             15
# 4  min_samples_split              5
# 5       n_estimators            366

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_forest, X_test, y_test)
# Out:
#                             R^2      RMSE
# RandomForestRegressor  0.670642  0.035176
# LinearRegression       0.639927  0.036779
# Ridge                  0.639911  0.036780
# KNeighborsRegressor    0.490895  0.043733
# DecisionTreeRegressor  0.490267  0.043760

# %% [markdown]
# ### 5.3. XGBoost

# %%
# Definir el modelo
xgb = xgb.XGBRegressor(tree_method='hist', objective='reg:squarederror')

# Definir la parrilla de hiperparámetros
param_dist = {
    'n_estimators': randint(200, 1200),
    'learning_rate': uniform(0.005, 0.3),
    'max_depth': randint(4, 15),
    'min_child_weight': randint(1, 15),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 15),
    'reg_alpha': uniform(0, 2),
    'reg_lambda': uniform(0, 2)
}

# Configurar la búsqueda aleatoria
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=50,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=29,
    n_jobs=-1
)

# Ejecutar la búsqueda
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000151F805E350>,
#                                         'reg_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000151F96B8C10>,
#                                         'reg_lambda': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000151F96B9950>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000151F9748690>},
#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# Obtener el mejor modelo
best_xgb = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#      Hiperparámetro        Valor
# 0  colsample_bytree     0.665290
# 1             gamma     0.234778
# 2     learning_rate     0.302431
# 3         max_depth     9.000000
# 4  min_child_weight     1.000000
# 5      n_estimators  1160.000000
# 6         reg_alpha     0.730427
# 7        reg_lambda     1.176509
# 8         subsample     0.873368

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_xgb, X_test, y_test)
# Out:
#                             R^2      RMSE
# XGBRegressor           0.724073  0.032196
# RandomForestRegressor  0.670642  0.035176
# LinearRegression       0.639927  0.036779
# Ridge                  0.639911  0.036780
# KNeighborsRegressor    0.490895  0.043733
# DecisionTreeRegressor  0.490267  0.043760

# %% [markdown]
# ### 5.4. SHAP Tree Model

# %% [markdown]
# Como el modelo basado en árboles que mejor predicción ha arrojado es el entrenado con XGBoost, escogemos a este para analizar sus valores SHAP.

# %%
# Crear el explicador de SHAP para el mejor modelo de árbol de decisión
explainer = shap.TreeExplainer(
    model=best_xgb,
    data=X_train,
    model_output='raw',
    feature_perturbation='interventional')

# Obtener los valores SHAP para todo el conjunto de prueba
shap_values = explainer(X_test)
# Out:
#  99%|===================| 10185/10268 [00:12<00:00]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librerís SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Force Plot
# Error en la visualización 3: matplotlib = True is not yet supported for force plots with multiple samples!
# Ejecutando visualización 4: Beeswarm Plot
# Ejecutando visualización 5: Scatter Plots

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='i1Q0O2E6SDNT1V3FY6OJ3'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6101234998563815, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue": 0.6598898747034765, "simIndex": 20.0, "features": {"0": {"effect": -0.00451188363134861, "value": 0.0}, "1": {"effect": 0.00011003015097230673, "value": 0.17905223175104135}, "2": {"effect": 0.0, "value": 1.0}, "3": {"effect": -0.0018148983246646822, "value": 0.0}, "4": {"effect": 0.0, "value": 0.0}, "5": {"effect": 0.0, "value": 0.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": 0.0, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": -0.0014565224369289353, "value": 0.1268610025517973}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": -8.037473598960787e-05, "value": 0.15773243839286433}, "12": {"effect": -0.0012821409432217479, "value": 0.6548623507611313}, "13": {"effect": 0.0, "value": 0.0}, "14": {"effect": 0.0009185612399596721, "value": 0.0}, "15": {"effect": 0.00016120380256325008, "value": 0.5272541507046521}, "16": {"effect": 0.005549342358426657, "value": 0.0}, "17": {"effect": 0.02797173965605907, "value": 0.9211698793217591}, "18": {"effect": 0.0006124723836546764, "value": 0.6211376798922876}, "19": {"effect": 0.0, "value": 0.7522608684733402}, "20": {"effect": 0.0, "value": 0.7329549128453421}, "21": {"effect": 0.0, "value": 1.0}, "22": {"effect": 0.0, "value": 0.0}, "23": {"effect": 0.0004689708538353443, "value": 0.9999999999999998}, "24": {"effect": 0.0, "value": 0.0}, "25": {"effect": 0.0, "value": 0.0}, "26": {"effect": 0.0, "value": 0.0}, "27": {"effect": 0.0004218544904142618, "value": 0.0}, "28": {"effect": 0.009307926340261475, "value": 0.42538007674874273}, "29": {"effect": 0.0, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.00048006510362029074, "value": 0.0}, "33": {"effect": 0.008305707334075122, "value": 0.0}, "34": {"effect": 0.0, "value": 0.0}, "35": {"effect": 0.0, "value": 0.0}, "36": {"effect": 0.0, "value": 0.0}, "37": {"effect": 0.0, "value": 0.0}, "38": {"effect": 0.0, "value": 0.0}, "39": {"effect": 0.0, "value": 0.0}, "40": {"effect": 0.0, "value": 0.0}, "41": {"effect": 0.0, "value": 1.0}, "42": {"effect": 0.0, "value": 0.0}, "43": {"effect": 0.0, "value": 0.0}, "44": {"effect": 0.0, "value": 0.0}, "45": {"effect": 0.0, "value": 0.0}, "46": {"effect": 0.0, "value": 0.0}, "47": {"effect": 0.0, "value": 0.0}, "48": {"effect": 0.0, "value": 0.0}, "49": {"effect": -0.0008222543587908149, "value": 0.0}, "50": {"effect": 0.0016229347157059237, "value": 1.0}, "51": {"effect": 0.0003031631000339985, "value": 0.0}, "52": {"effect": 0.002215437302365899, "value": 0.0}, "53": {"effect": 0.0012850404460914434, "value": 1.0}}}, {"outValue": 0.5805744662299913, "simIndex": 39.0, "features": {"0": {"effect": -0.0014172682873322628, "value": 0.0}, "1": {"e ...

# %% [markdown]
# ## 6. SVM

# %%
# Definir el modelo
svr = LinearSVR()

# Definir la parrilla de hiperparámetros
param_dist = {
    'C': uniform(0.1, 10),
    'epsilon': uniform(0.01, 1),
    'max_iter': randint(100, 1000)
}

# Configurar la búsqueda aleatoria
random_search = RandomizedSearchCV(
    estimator=svr,
    param_distributions=param_dist,
    n_iter=200,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=29,
    n_jobs=-1
)

# Ejecutar la búsqueda
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\svm\_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=LinearSVR(), n_iter=200, n_jobs=-1,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000151F991B290>,
#                                         'epsilon': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000151F93E7750>,
#                                         'max_iter': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000151F99EA310>},
#                    random_state=29, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
# Obtener el mejor modelo
best_svr = random_search.best_estimator_

# Imprimime mejores hiperparámetros
df_best_params(random_search)
# Out:
# Mejores hiperparámetros encontrados:
#   Hiperparámetro       Valor
# 0              C    0.154085
# 1        epsilon    0.038436
# 2       max_iter  679.000000

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(best_svr, X_test, y_test)
# Out:
#                             R^2      RMSE
# XGBRegressor           0.724073  0.032196
# RandomForestRegressor  0.670642  0.035176
# LinearSVR              0.664493  0.035502
# LinearRegression       0.639927  0.036779
# Ridge                  0.639911  0.036780
# KNeighborsRegressor    0.490895  0.043733
# DecisionTreeRegressor  0.490267  0.043760

# %%
# Crear el explicador SHAP para SVR
explainer = shap.KernelExplainer(
    model=best_svr.predict,  
    data=X_train[:100],
    link="identity" 
)

# Calcular valores SHAP para un subconjunto de datos de prueba
shap_values = explainer(X_test[:100])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librerís SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Force Plot
# Error en la visualización 3: matplotlib = True is not yet supported for force plots with multiple samples!
# Ejecutando visualización 4: Beeswarm Plot
# Ejecutando visualización 5: Scatter Plots

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='iQ56TF9CIQ3EF9QWD945M'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6138347075545403, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue": 0.6972116888805824, "simIndex": 1.0, "features": {"0": {"effect": -0.012918204027739171, "value": 0.0}, "1": {"effect": 0.0012744183213999813, "value": 0.17905223175104135}, "2": {"effect": -0.008186949006633254, "value": 1.0}, "3": {"effect": 0.026037171616903013, "value": 0.0}, "4": {"effect": 0.00017135628518572085, "value": 0.0}, "5": {"effect": -0.001805697521616427, "value": 0.0}, "6": {"effect": -0.002103551238576928, "value": 0.0}, "7": {"effect": -0.0022817332919292097, "value": 0.0}, "8": {"effect": -0.001273308514043113, "value": 0.0}, "9": {"effect": 0.0004383044794557973, "value": 0.1268610025517973}, "10": {"effect": 0.004193155476638449, "value": 0.0}, "11": {"effect": 0.0006673926479514964, "value": 0.15773243839286433}, "12": {"effect": 0.022646617952868753, "value": 0.6548623507611313}, "13": {"effect": 0.0010049431180751706, "value": 0.0}, "14": {"effect": -0.014302821326478532, "value": 0.0}, "15": {"effect": -0.0006598703987409764, "value": 0.5272541507046521}, "16": {"effect": -0.00041046131833689036, "value": 0.0}, "17": {"effect": 0.024990476479733806, "value": 0.9211698793217591}, "18": {"effect": 0.0022006746380363366, "value": 0.6211376798922876}, "19": {"effect": -0.0004689652272935103, "value": 0.7522608684733402}, "20": {"effect": 0.0009918362746299976, "value": 0.7329549128453421}, "21": {"effect": -0.008186949006633207, "value": 1.0}, "22": {"effect": 0.001605736676209589, "value": 0.0}, "23": {"effect": 2.89617684075142e-05, "value": 0.9999999999999998}, "24": {"effect": 0.00012153883969586979, "value": 0.0}, "25": {"effect": 0.0005806996610578086, "value": 0.0}, "26": {"effect": 0.00030883119948889136, "value": 0.0}, "27": {"effect": 0.0010856661444487718, "value": 0.0}, "28": {"effect": 0.023871050746999863, "value": 0.42538007674874273}, "29": {"effect": 5.375467317814711e-05, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.00258980892201827, "value": 0.0}, "33": {"effect": 0.007652862131914789, "value": 0.0}, "34": {"effect": -0.00033857130196073064, "value": 0.0}, "35": {"effect": -0.0002934858916784739, "value": 0.0}, "36": {"effect": 9.709743936905292e-05, "value": 0.0}, "37": {"effect": -4.032923032648855e-06, "value": 0.0}, "38": {"effect": -3.3490856252055024e-05, "value": 0.0}, "39": {"effect": 0.00014103571255520705, "value": 0.0}, "40": {"effect": 0.00011184716713885377, "value": 0.0}, "41": {"effect": 0.00029748582851401933, "value": 1.0}, "42": {"effect": 0.0007920034746703771, "value": 0.0}, "43": {"effect": 0.0006488273161523557, "value": 0.0}, "44": {"effect": -0.0003519073418810427, "value": 0.0}, "45": {"effect": 0.001206116439653601, "value": 0.0}, "46":  ...

# %% [markdown]
# ## 7. Red Neuronal Multicapa

# %%
# Función para el ajuste de la tasa de aprendizaje
def lr_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.95

# Crear el modelo
dense = Sequential()

# Capa de entrada con normalización y activación LeakyReLU
dense.add(Input(shape=(X_train.shape[1],)))
dense.add(Dense(256, kernel_regularizer=l2(0.005)))
dense.add(BatchNormalization()) 
dense.add(LeakyReLU(negative_slope=0.01))

# Capas ocultas con activación LeakyReLU y BatchNormalization
dense.add(Dense(128, kernel_regularizer=l2(0.005)))
dense.add(BatchNormalization())
dense.add(LeakyReLU(negative_slope=0.01))

dense.add(Dense(128, kernel_regularizer=l2(0.005)))
dense.add(BatchNormalization())
dense.add(LeakyReLU(negative_slope=0.01))

# Dropout para evitar sobreajuste
dense.add(Dropout(0.3))

# Capa de salida (regresión)
dense.add(Dense(1, activation="linear"))

# Compilar el modelo con el optimizador Adam
optimizer = Adam(learning_rate=0.001)
dense.compile(optimizer=optimizer, loss="mse", metrics=["mean_squared_error"])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_callback = LearningRateScheduler(lr_scheduler)

# Entrenamiento del modelo
history = dense.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, 
                  batch_size=128, callbacks=[early_stopping, lr_callback])
# Out:
# Epoch 1/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.4428 - mean_squared_error: 0.7125 - val_loss: 1.0553 - val_mean_squared_error: 0.0156 - learning_rate: 0.0010
# Epoch 2/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9421 - mean_squared_error: 0.0904 - val_loss: 0.4172 - val_mean_squared_error: 0.0111 - learning_rate: 0.0010
# Epoch 3/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3450 - mean_squared_error: 0.0264 - val_loss: 0.1394 - val_mean_squared_error: 0.0056 - learning_rate: 0.0010
# Epoch 4/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1159 - mean_squared_error: 0.0128 - val_loss: 0.0465 - val_mean_squared_error: 0.0051 - learning_rate: 0.0010
# Epoch 5/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0401 - mean_squared_error: 0.0082 - val_loss: 0.0191 - val_mean_squared_error: 0.0061 - learning_rate: 0.0010
# Epoch 6/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0162 - mean_squared_error: 0.0061 - val_loss: 0.0089 - val_mean_squared_error: 0.0041 - learning_rate: 0.0010
# Epoch 7/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0082 - mean_squared_error: 0.0046 - val_loss: 0.0042 - val_mean_squared_error: 0.0021 - learning_rate: 0.0010
# Epoch 8/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0055 - mean_squared_error: 0.0038 - val_loss: 0.0064 - val_mean_squared_error: 0.0052 - learning_rate: 0.0010
# Epoch 9/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0043 - mean_squared_error: 0.0033 - val_loss: 0.0034 - val_mean_squared_error: 0.0024 - learning_rate: 0.0010
# Epoch 10/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0037 - mean_squared_error: 0.0028 - val_loss: 0.0031 - val_mean_squared_error: 0.0023 - learning_rate: 0.0010
# Epoch 11/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0029 - mean_squared_error: 0.0023 - val_loss: 0.0021 - val_mean_squared_error: 0.0014 - learning_rate: 9.5000e-04
# Epoch 12/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0027 - mean_squared_error: 0.0020 - val_loss: 0.0023 - val_mean_squared_error: 0.0017 - learning_rate: 9.0250e-04
# Epoch 13/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0023 - mean_squared_error: 0.0017 - val_loss: 0.0028 - val_mean_squared_error: 0.0023 - learning_rate: 8.5737e-04
# Epoch 14/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0021 - mean_squared_error: 0.0016 - val_loss: 0.0019 - val_mean_squared_error: 0.0014 - learning_rate: 8.1451e-04
# Epoch 15/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0018 - mean_squared_error: 0.0014 - val_loss: 0.0018 - val_mean_squared_error: 0.0014 - learning_rate: 7.7378e-04
# Epoch 16/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0013 - val_loss: 0.0016 - val_mean_squared_error: 0.0013 - learning_rate: 7.3509e-04
# Epoch 17/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0013 - val_loss: 0.0016 - val_mean_squared_error: 0.0014 - learning_rate: 6.9834e-04
# Epoch 18/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0012 - val_loss: 0.0034 - val_mean_squared_error: 0.0032 - learning_rate: 6.6342e-04
# Epoch 19/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0014 - mean_squared_error: 0.0012 - val_loss: 0.0014 - val_mean_squared_error: 0.0013 - learning_rate: 6.3025e-04
# Epoch 20/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0013 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0012 - learning_rate: 5.9874e-04
# Epoch 21/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0014 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_squared_error: 0.0011 - learning_rate: 5.6880e-04
# Epoch 22/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0013 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0013 - learning_rate: 5.4036e-04
# Epoch 23/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0012 - learning_rate: 5.1334e-04
# Epoch 24/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0012 - learning_rate: 4.8767e-04
# Epoch 25/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0011 - learning_rate: 4.6329e-04
# Epoch 26/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0013 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0011 - learning_rate: 4.4013e-04
# Epoch 27/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0012 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0010 - learning_rate: 4.1812e-04
# Epoch 28/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0012 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0012 - learning_rate: 3.9721e-04
# Epoch 29/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0011 - learning_rate: 3.7735e-04
# Epoch 30/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - mean_squared_error: 0.0010 - val_loss: 0.0013 - val_mean_squared_error: 0.0012 - learning_rate: 3.5849e-04
# Epoch 31/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0012 - mean_squared_error: 0.0010 - val_loss: 0.0012 - val_mean_squared_error: 0.0011 - learning_rate: 3.4056e-04
# Epoch 32/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0012 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0011 - learning_rate: 3.2353e-04
# Epoch 33/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - mean_squared_error: 0.0010 - val_loss: 0.0013 - val_mean_squared_error: 0.0012 - learning_rate: 3.0736e-04
# Epoch 34/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - mean_squared_error: 9.7309e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0011 - learning_rate: 2.9199e-04
# Epoch 35/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - mean_squared_error: 9.8398e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0011 - learning_rate: 2.7739e-04
# Epoch 36/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - mean_squared_error: 0.0010 - val_loss: 0.0013 - val_mean_squared_error: 0.0012 - learning_rate: 2.6352e-04
# Epoch 37/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - mean_squared_error: 9.8859e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0012 - learning_rate: 2.5034e-04
# Epoch 38/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - mean_squared_error: 0.0010 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 2.3783e-04
# Epoch 39/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - mean_squared_error: 9.8752e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0011 - learning_rate: 2.2594e-04
# Epoch 40/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0011 - mean_squared_error: 9.9361e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 2.1464e-04
# Epoch 41/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - mean_squared_error: 9.9413e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 2.0391e-04
# Epoch 42/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - mean_squared_error: 9.5547e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 1.9371e-04
# Epoch 43/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - mean_squared_error: 9.7866e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 1.8403e-04
# Epoch 44/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0011 - mean_squared_error: 9.8307e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0011 - learning_rate: 1.7482e-04
# Epoch 45/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0011 - mean_squared_error: 9.7095e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - learning_rate: 1.6608e-04
# Epoch 46/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0010 - mean_squared_error: 9.2322e-04 - val_loss: 0.0011 - val_mean_squared_error: 9.8334e-04 - learning_rate: 1.5778e-04
# Epoch 47/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0011 - mean_squared_error: 9.6708e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 1.4989e-04
# Epoch 48/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0010 - mean_squared_error: 9.4074e-04 - val_loss: 0.0011 - val_mean_squared_error: 9.8522e-04 - learning_rate: 1.4240e-04
# Epoch 49/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0010 - mean_squared_error: 9.5384e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.5160e-04 - learning_rate: 1.3528e-04
# Epoch 50/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - mean_squared_error: 9.7339e-04 - val_loss: 0.0011 - val_mean_squared_error: 9.7492e-04 - learning_rate: 1.2851e-04
# Epoch 51/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.9753e-04 - mean_squared_error: 9.1208e-04 - val_loss: 0.0011 - val_mean_squared_error: 9.9009e-04 - learning_rate: 1.2209e-04
# Epoch 52/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0010 - mean_squared_error: 9.2101e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.5645e-04 - learning_rate: 1.1598e-04
# Epoch 53/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0011 - mean_squared_error: 9.7458e-04 - val_loss: 0.0011 - val_mean_squared_error: 9.7453e-04 - learning_rate: 1.1018e-04
# Epoch 54/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - mean_squared_error: 9.6768e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.5590e-04 - learning_rate: 1.0467e-04
# Epoch 55/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mean_squared_error: 9.2586e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.5957e-04 - learning_rate: 9.9440e-05
# Epoch 56/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0010 - mean_squared_error: 9.4668e-04 - val_loss: 0.0011 - val_mean_squared_error: 9.7749e-04 - learning_rate: 9.4468e-05
# Epoch 57/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.8612e-04 - mean_squared_error: 9.0460e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.4709e-04 - learning_rate: 8.9745e-05
# Epoch 58/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0010 - mean_squared_error: 9.2599e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.2205e-04 - learning_rate: 8.5258e-05
# Epoch 59/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0010 - mean_squared_error: 9.2434e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.3142e-04 - learning_rate: 8.0995e-05
# Epoch 60/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.9432e-04 - mean_squared_error: 9.1498e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.5179e-04 - learning_rate: 7.6945e-05
# Epoch 61/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.9720e-04 - mean_squared_error: 9.1813e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.2629e-04 - learning_rate: 7.3098e-05
# Epoch 62/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.7297e-04 - mean_squared_error: 8.9442e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.2748e-04 - learning_rate: 6.9443e-05
# Epoch 63/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.8859e-04 - mean_squared_error: 9.0991e-04 - val_loss: 9.9378e-04 - val_mean_squared_error: 9.1528e-04 - learning_rate: 6.5971e-05
# Epoch 64/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.9251e-04 - mean_squared_error: 9.1412e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.4555e-04 - learning_rate: 6.2672e-05
# Epoch 65/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 9.8099e-04 - mean_squared_error: 9.0263e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 5.9539e-05
# Epoch 66/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0010 - mean_squared_error: 9.2358e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0010 - learning_rate: 5.6562e-05
# Epoch 67/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0010 - mean_squared_error: 9.4340e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.2933e-04 - learning_rate: 5.3734e-05
# Epoch 68/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.8273e-04 - mean_squared_error: 8.9653e-04 - val_loss: 9.7713e-04 - val_mean_squared_error: 8.9460e-04 - learning_rate: 5.1047e-05
# Epoch 69/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.7706e-04 - mean_squared_error: 8.9523e-04 - val_loss: 9.8776e-04 - val_mean_squared_error: 9.0327e-04 - learning_rate: 4.8495e-05
# Epoch 70/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.9890e-04 - mean_squared_error: 9.1505e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.2428e-04 - learning_rate: 4.6070e-05
# Epoch 71/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.6698e-04 - mean_squared_error: 8.8673e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.5351e-04 - learning_rate: 4.3766e-05
# Epoch 72/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5117e-04 - mean_squared_error: 8.7069e-04 - val_loss: 9.9183e-04 - val_mean_squared_error: 9.1149e-04 - learning_rate: 4.1578e-05
# Epoch 73/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.8607e-04 - mean_squared_error: 9.0573e-04 - val_loss: 9.7941e-04 - val_mean_squared_error: 8.9835e-04 - learning_rate: 3.9499e-05
# Epoch 74/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.9794e-04 - mean_squared_error: 9.1762e-04 - val_loss: 0.0010 - val_mean_squared_error: 9.2057e-04 - learning_rate: 3.7524e-05
# Epoch 75/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4996e-04 - mean_squared_error: 8.7094e-04 - val_loss: 9.8391e-04 - val_mean_squared_error: 9.0611e-04 - learning_rate: 3.5648e-05
# Epoch 76/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.4419e-04 - mean_squared_error: 8.6582e-04 - val_loss: 9.9032e-04 - val_mean_squared_error: 9.1229e-04 - learning_rate: 3.3866e-05
# Epoch 77/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.8751e-04 - mean_squared_error: 9.0903e-04 - val_loss: 9.8414e-04 - val_mean_squared_error: 9.0257e-04 - learning_rate: 3.2172e-05
# Epoch 78/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.8321e-04 - mean_squared_error: 9.0222e-04 - val_loss: 9.7618e-04 - val_mean_squared_error: 8.9741e-04 - learning_rate: 3.0564e-05
# Epoch 79/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0010 - mean_squared_error: 9.3492e-04 - val_loss: 9.6540e-04 - val_mean_squared_error: 8.8684e-04 - learning_rate: 2.9035e-05
# Epoch 80/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.6304e-04 - mean_squared_error: 8.8484e-04 - val_loss: 9.8387e-04 - val_mean_squared_error: 9.0594e-04 - learning_rate: 2.7584e-05
# Epoch 81/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5377e-04 - mean_squared_error: 8.7592e-04 - val_loss: 9.8579e-04 - val_mean_squared_error: 9.0790e-04 - learning_rate: 2.6205e-05
# Epoch 82/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.8564e-04 - mean_squared_error: 9.0799e-04 - val_loss: 9.6113e-04 - val_mean_squared_error: 8.8334e-04 - learning_rate: 2.4894e-05
# Epoch 83/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4142e-04 - mean_squared_error: 8.6384e-04 - val_loss: 9.5777e-04 - val_mean_squared_error: 8.7910e-04 - learning_rate: 2.3650e-05
# Epoch 84/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4549e-04 - mean_squared_error: 8.6744e-04 - val_loss: 9.6831e-04 - val_mean_squared_error: 8.9110e-04 - learning_rate: 2.2467e-05
# Epoch 85/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.6211e-04 - mean_squared_error: 8.8445e-04 - val_loss: 9.5914e-04 - val_mean_squared_error: 8.8071e-04 - learning_rate: 2.1344e-05
# Epoch 86/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.4744e-04 - mean_squared_error: 8.6957e-04 - val_loss: 9.5769e-04 - val_mean_squared_error: 8.7998e-04 - learning_rate: 2.0277e-05
# Epoch 87/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5126e-04 - mean_squared_error: 8.7327e-04 - val_loss: 9.7361e-04 - val_mean_squared_error: 8.9610e-04 - learning_rate: 1.9263e-05
# Epoch 88/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4518e-04 - mean_squared_error: 8.6745e-04 - val_loss: 9.5559e-04 - val_mean_squared_error: 8.7774e-04 - learning_rate: 1.8300e-05
# Epoch 89/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.6064e-04 - mean_squared_error: 8.8298e-04 - val_loss: 9.5220e-04 - val_mean_squared_error: 8.7479e-04 - learning_rate: 1.7385e-05
# Epoch 90/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.0813e-04 - mean_squared_error: 8.3065e-04 - val_loss: 9.5158e-04 - val_mean_squared_error: 8.7418e-04 - learning_rate: 1.6515e-05
# Epoch 91/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.6359e-04 - mean_squared_error: 8.8591e-04 - val_loss: 9.4807e-04 - val_mean_squared_error: 8.6985e-04 - learning_rate: 1.5690e-05
# Epoch 92/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4993e-04 - mean_squared_error: 8.7194e-04 - val_loss: 9.5392e-04 - val_mean_squared_error: 8.7614e-04 - learning_rate: 1.4905e-05
# Epoch 93/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.2721e-04 - mean_squared_error: 8.4937e-04 - val_loss: 9.4931e-04 - val_mean_squared_error: 8.7147e-04 - learning_rate: 1.4160e-05
# Epoch 94/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4127e-04 - mean_squared_error: 8.6355e-04 - val_loss: 9.5270e-04 - val_mean_squared_error: 8.7496e-04 - learning_rate: 1.3452e-05
# Epoch 95/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.3572e-04 - mean_squared_error: 8.5796e-04 - val_loss: 9.6982e-04 - val_mean_squared_error: 8.9201e-04 - learning_rate: 1.2779e-05
# Epoch 96/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.4663e-04 - mean_squared_error: 8.6864e-04 - val_loss: 9.6236e-04 - val_mean_squared_error: 8.8484e-04 - learning_rate: 1.2140e-05
# Epoch 97/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.3651e-04 - mean_squared_error: 8.5857e-04 - val_loss: 9.4479e-04 - val_mean_squared_error: 8.6633e-04 - learning_rate: 1.1533e-05
# Epoch 98/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.1848e-04 - mean_squared_error: 8.4004e-04 - val_loss: 9.5224e-04 - val_mean_squared_error: 8.7380e-04 - learning_rate: 1.0957e-05
# Epoch 99/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.1214e-04 - mean_squared_error: 8.3393e-04 - val_loss: 9.5297e-04 - val_mean_squared_error: 8.7476e-04 - learning_rate: 1.0409e-05
# Epoch 100/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.1548e-04 - mean_squared_error: 8.3723e-04 - val_loss: 9.4327e-04 - val_mean_squared_error: 8.6517e-04 - learning_rate: 9.8884e-06

# %%
# Graficar los valores de error absoluto medio durante el entrenamiento
plt.figure(figsize=(13,6))
plt.plot(history.history['mean_squared_error'], label='Entrenamiento (MSE)')
plt.plot(history.history['val_mean_squared_error'], label='Validación (MSE)')
plt.title('Error Cuadrático Medio (MSE) durante el entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
# Graficar la pérdida
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Evolución de la pérdida a lo largo de las épocas')
plt.show()

# %%
y_pred_train = dense.predict(X_train)
y_pred_test = dense.predict(X_test)

plt.figure(figsize=(8,5))
x_vals = np.linspace(0, 1, 100)
plt.plot(x_vals, x_vals, color="black", linestyle="dashed", label="Referencia (y=x)")
plt.scatter(y_train, y_pred_train, label="Entrenamiento", alpha=0.6)
plt.scatter(y_test, y_pred_test, label="Validación", alpha=0.6, marker="x")
plt.xlabel("Valor Real")
plt.ylabel("Predicción")
plt.legend()
plt.title("Comparación entre Predicciones y Valores Reales")
plt.show()
# Out:
# 1284/1284 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# import tensorflow as tf
# import matplotlib.pyplot as plt
# from tensorflow.keras.losses import mean_squared_error  # 🔹 Importar mean_squared_error

# # Definir función para monitorear gradientes
# def get_gradients(model, X, y):
#     with tf.GradientTape() as tape:
#         preds = model(X, training=True)  # Asegurar que se calcule en modo entrenamiento
#         loss = mean_squared_error(y, preds)
#     return tape.gradient(loss, model.trainable_variables)

# # Obtener gradientes en la primera época
# grad_start = get_gradients(model, X_train[:100], y_train[:100])

# # Entrenar el modelo
# history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, verbose=0)

# # Obtener gradientes en la última época
# grad_end = get_gradients(model, X_train[:100], y_train[:100])

# # Procesar gradientes: convertir a escalares para cada capa
# grad_start = [tf.reduce_mean(tf.abs(g)).numpy() for g in grad_start]
# grad_end = [tf.reduce_mean(tf.abs(g)).numpy() for g in grad_end]

# # Visualizar la evolución de los gradientes
# plt.figure(figsize=(8, 5))
# plt.plot(grad_start, label="Gradientes Iniciales", marker="o")
# plt.plot(grad_end, label="Gradientes Finales", marker="s", linestyle="dashed")
# plt.xlabel("Capas")
# plt.ylabel("Magnitud del Gradiente")
# plt.legend()
# plt.title("Evolución de los Gradientes Durante el Entrenamiento")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[55], line 3
#       1 import tensorflow as tf
#       2 import matplotlib.pyplot as plt
# ----> 3 from tensorflow.keras.losses import mean_squared_error  # 🔹 Importar mean_squared_error
#       5 # Definir función para monitorear gradientes
#       6 def get_gradients(model, X, y):
#
# ImportError: cannot import name 'mean_squared_error' from 'tensorflow.keras.losses' (C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\_tf_keras\keras\losses\__init__.py)

# %%
# Evalúa el modelo entrenado con los datos de prueba
evaluar_modelos(dense, X_test, y_test)
# Out:
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#                             R^2      RMSE
# Sequential             0.769704  0.029414
# XGBRegressor           0.724073  0.032196
# RandomForestRegressor  0.670642  0.035176
# LinearSVR              0.664493  0.035502
# LinearRegression       0.639927  0.036779
# Ridge                  0.639911  0.036780
# KNeighborsRegressor    0.490895  0.043733
# DecisionTreeRegressor  0.490267  0.043760

# %%
# Crear el explicador SHAP para SVR
explainer = shap.KernelExplainer(
    model=best_svr.predict,  
    data=X_train[:100],
    link="identity" 
)

# Calcular valores SHAP para un subconjunto de datos de prueba
shap_values = explainer(X_test[:100])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librerís SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Ejecutando visualización 3: Force Plot
# Error en la visualización 3: matplotlib = True is not yet supported for force plots with multiple samples!
# Ejecutando visualización 4: Beeswarm Plot
# Ejecutando visualización 5: Scatter Plots

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# <div id='i643I2VOQRC402GLUIQ9D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6138347075545403, "link": "identity", "featureNames": ["Tot_Closed_TL", "Tot_Active_TL", "pct_active_tl", "pct_closed_tl", "Tot_Missed_Pmnt", "Auto_TL", "CC_TL", "Home_TL", "PL_TL", "Secured_TL", "Unsecured_TL", "Other_TL", "Age_Oldest_TL", "Tot_TL_closed_pca", "pct_tl_open_pca", "time_since_recent_payment", "recent_level_of_deliq", "time_since_recent_enq", "AGE", "NETMONTHLYINCOME", "Time_With_Curr_Empr", "pct_of_active_TLs_ever", "pct_opened_TLs_L6m_of_L12m", "pct_currentBal_all_TL", "CC_utilization", "PL_utilization", "num_times_dpd", "max_deliq_pca", "num_std_pca", "num_sub_pca", "num_dbt_pca", "num_lss_pca", "CC_enq_pca", "pct_PL_enq_pca", "MARITALSTATUS_Single", "EDUCATION_GRADUATE", "EDUCATION_OTHERS", "EDUCATION_POST-GRADUATE", "EDUCATION_PROFESSIONAL", "EDUCATION_SSC", "EDUCATION_UNDER GRADUATE", "GENDER_M", "CC_Flag_True", "PL_Flag_True", "HL_Flag_True", "GL_Flag_True", "last_prod_enq2_CC", "last_prod_enq2_ConsumerLoan", "last_prod_enq2_HL", "last_prod_enq2_PL", "last_prod_enq2_others", "time_since_recent_deliquency_class_10-19 days", "time_since_recent_deliquency_class_20+ days", "time_since_recent_deliquency_class_Never"], "explanations": [{"outValue": 0.6972116888805824, "simIndex": 1.0, "features": {"0": {"effect": -0.012918287320123798, "value": 0.0}, "1": {"effect": 0.0012741906087852003, "value": 0.17905223175104135}, "2": {"effect": -0.008187017512864153, "value": 1.0}, "3": {"effect": 0.0260370971287416, "value": 0.0}, "4": {"effect": 0.00017134395647809672, "value": 0.0}, "5": {"effect": -0.0018057885597962521, "value": 0.0}, "6": {"effect": -0.002103574493070152, "value": 0.0}, "7": {"effect": -0.0022819864881954226, "value": 0.0}, "8": {"effect": -0.001273585131396694, "value": 0.0}, "9": {"effect": 0.0004382724902214641, "value": 0.1268610025517973}, "10": {"effect": 0.004193148986154107, "value": 0.0}, "11": {"effect": 0.000667411616783999, "value": 0.15773243839286433}, "12": {"effect": 0.022646771661117577, "value": 0.6548623507611313}, "13": {"effect": 0.0010046966797579607, "value": 0.0}, "14": {"effect": -0.01430282090550079, "value": 0.0}, "15": {"effect": -0.000659835089120673, "value": 0.5272541507046521}, "16": {"effect": -0.00041029807735382617, "value": 0.0}, "17": {"effect": 0.024990366426555995, "value": 0.9211698793217591}, "18": {"effect": 0.0022005953306570947, "value": 0.6211376798922876}, "19": {"effect": -0.0004690578870417807, "value": 0.7522608684733402}, "20": {"effect": 0.000991785546663853, "value": 0.7329549128453421}, "21": {"effect": -0.008186789730174539, "value": 1.0}, "22": {"effect": 0.0016055903149020162, "value": 0.0}, "23": {"effect": 2.9051296004453604e-05, "value": 0.9999999999999998}, "24": {"effect": 0.00012134139952284608, "value": 0.0}, "25": {"effect": 0.0005806067533047555, "value": 0.0}, "26": {"effect": 0.00030874563738223095, "value": 0.0}, "27": {"effect": 0.0010854365491608107, "value": 0.0}, "28": {"effect": 0.023870977558377342, "value": 0.42538007674874273}, "29": {"effect": 5.3697173390859814e-05, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.002589699372141677, "value": 0.0}, "33": {"effect": 0.007652763050933025, "value": 0.0}, "34": {"effect": -0.000338589768360092, "value": 0.0}, "35": {"effect": -0.00029346462563802783, "value": 0.0}, "36": {"effect": 9.714496266039266e-05, "value": 0.0}, "37": {"effect": 0.0, "value": 0.0}, "38": {"effect": -3.354408564134808e-05, "value": 0.0}, "39": {"effect": 0.00014069034163915, "value": 0.0}, "40": {"effect": 0.00011152463601546057, "value": 0.0}, "41": {"effect": 0.0002973361859182916, "value": 1.0}, "42": {"effect": 0.0007921061236336552, "value": 0.0}, "43": {"effect": 0.0006487984468322205, "value": 0.0}, "44": {"effect": -0.00035199325729375845, "value": 0.0}, "45": {"effect": 0.0012060074135745898, "value": 0.0}, "46": {"effect": -0.000353342 ...

# %% [markdown]
# ### 7.1. Simple Dense Neural Network

# %%
# Crear un modelo sin BatchNormalization y Dropout
rnn_simplificado = Sequential()
rnn_simplificado.add(Input(shape=(X_train.shape[1],)))
rnn_simplificado.add(Dense(256, kernel_regularizer=l2(0.005), activation='relu'))
rnn_simplificado.add(Dense(128, kernel_regularizer=l2(0.005), activation='relu'))
rnn_simplificado.add(Dense(128, kernel_regularizer=l2(0.005), activation='relu'))
rnn_simplificado.add(Dense(1, activation="linear"))

# Compilar el modelo
rnn_simplificado.compile(optimizer='adam', loss="mse", metrics=["mean_squared_error"])

# Entrenar y calcular SHAP
history = rnn_simplificado.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=128, callbacks=[early_stopping, lr_callback])
# Out:
# Epoch 1/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8559 - mean_squared_error: 0.0125 - val_loss: 0.0259 - val_mean_squared_error: 0.0015 - learning_rate: 0.0010
# Epoch 2/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0159 - mean_squared_error: 0.0014 - val_loss: 0.0049 - val_mean_squared_error: 0.0019 - learning_rate: 0.0010
# Epoch 3/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0042 - mean_squared_error: 0.0017 - val_loss: 0.0036 - val_mean_squared_error: 0.0019 - learning_rate: 0.0010
# Epoch 4/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0034 - mean_squared_error: 0.0017 - val_loss: 0.0035 - val_mean_squared_error: 0.0018 - learning_rate: 0.0010
# Epoch 5/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0033 - mean_squared_error: 0.0016 - val_loss: 0.0034 - val_mean_squared_error: 0.0017 - learning_rate: 0.0010
# Epoch 6/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0032 - mean_squared_error: 0.0016 - val_loss: 0.0033 - val_mean_squared_error: 0.0016 - learning_rate: 0.0010
# Epoch 7/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0031 - mean_squared_error: 0.0015 - val_loss: 0.0032 - val_mean_squared_error: 0.0016 - learning_rate: 0.0010
# Epoch 8/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0031 - mean_squared_error: 0.0015 - val_loss: 0.0032 - val_mean_squared_error: 0.0017 - learning_rate: 0.0010
# Epoch 9/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0030 - mean_squared_error: 0.0014 - val_loss: 0.0031 - val_mean_squared_error: 0.0015 - learning_rate: 0.0010
# Epoch 10/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0029 - mean_squared_error: 0.0013 - val_loss: 0.0030 - val_mean_squared_error: 0.0013 - learning_rate: 0.0010
# Epoch 11/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0028 - mean_squared_error: 0.0013 - val_loss: 0.0029 - val_mean_squared_error: 0.0014 - learning_rate: 9.5000e-04
# Epoch 12/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0028 - mean_squared_error: 0.0012 - val_loss: 0.0028 - val_mean_squared_error: 0.0013 - learning_rate: 9.0250e-04
# Epoch 13/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0027 - mean_squared_error: 0.0012 - val_loss: 0.0028 - val_mean_squared_error: 0.0013 - learning_rate: 8.5737e-04
# Epoch 14/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0026 - mean_squared_error: 0.0012 - val_loss: 0.0027 - val_mean_squared_error: 0.0012 - learning_rate: 8.1451e-04
# Epoch 15/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0026 - mean_squared_error: 0.0012 - val_loss: 0.0028 - val_mean_squared_error: 0.0014 - learning_rate: 7.7378e-04
# Epoch 16/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0026 - mean_squared_error: 0.0011 - val_loss: 0.0027 - val_mean_squared_error: 0.0012 - learning_rate: 7.3509e-04
# Epoch 17/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0026 - mean_squared_error: 0.0011 - val_loss: 0.0026 - val_mean_squared_error: 0.0012 - learning_rate: 6.9834e-04
# Epoch 18/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0024 - mean_squared_error: 0.0010 - val_loss: 0.0025 - val_mean_squared_error: 0.0012 - learning_rate: 6.6342e-04
# Epoch 19/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0024 - mean_squared_error: 0.0010 - val_loss: 0.0025 - val_mean_squared_error: 0.0011 - learning_rate: 6.3025e-04
# Epoch 20/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0024 - mean_squared_error: 0.0011 - val_loss: 0.0025 - val_mean_squared_error: 0.0012 - learning_rate: 5.9874e-04
# Epoch 21/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023 - mean_squared_error: 9.7217e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0012 - learning_rate: 5.6880e-04
# Epoch 22/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023 - mean_squared_error: 9.9506e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0012 - learning_rate: 5.4036e-04
# Epoch 23/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023 - mean_squared_error: 9.6718e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0011 - learning_rate: 5.1334e-04
# Epoch 24/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0022 - mean_squared_error: 9.5749e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0011 - learning_rate: 4.8767e-04
# Epoch 25/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0022 - mean_squared_error: 9.8417e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0011 - learning_rate: 4.6329e-04
# Epoch 26/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0022 - mean_squared_error: 9.2490e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0010 - learning_rate: 4.4013e-04
# Epoch 27/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0022 - mean_squared_error: 9.3495e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0012 - learning_rate: 4.1812e-04
# Epoch 28/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0022 - mean_squared_error: 9.5050e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0010 - learning_rate: 3.9721e-04
# Epoch 29/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0021 - mean_squared_error: 8.8789e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0010 - learning_rate: 3.7735e-04
# Epoch 30/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0021 - mean_squared_error: 9.1277e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0010 - learning_rate: 3.5849e-04
# Epoch 31/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0021 - mean_squared_error: 9.0404e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0010 - learning_rate: 3.4056e-04
# Epoch 32/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0021 - mean_squared_error: 8.9537e-04 - val_loss: 0.0022 - val_mean_squared_error: 9.9969e-04 - learning_rate: 3.2353e-04
# Epoch 33/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0020 - mean_squared_error: 8.7009e-04 - val_loss: 0.0021 - val_mean_squared_error: 9.9607e-04 - learning_rate: 3.0736e-04
# Epoch 34/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0020 - mean_squared_error: 9.1480e-04 - val_loss: 0.0021 - val_mean_squared_error: 9.8230e-04 - learning_rate: 2.9199e-04
# Epoch 35/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0020 - mean_squared_error: 8.6442e-04 - val_loss: 0.0021 - val_mean_squared_error: 0.0010 - learning_rate: 2.7739e-04
# Epoch 36/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0020 - mean_squared_error: 8.4439e-04 - val_loss: 0.0021 - val_mean_squared_error: 9.9413e-04 - learning_rate: 2.6352e-04
# Epoch 37/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0020 - mean_squared_error: 8.6265e-04 - val_loss: 0.0021 - val_mean_squared_error: 9.5595e-04 - learning_rate: 2.5034e-04
# Epoch 38/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - mean_squared_error: 8.4600e-04 - val_loss: 0.0021 - val_mean_squared_error: 9.6306e-04 - learning_rate: 2.3783e-04
# Epoch 39/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - mean_squared_error: 8.5122e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.6235e-04 - learning_rate: 2.2594e-04
# Epoch 40/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - mean_squared_error: 8.4363e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.4800e-04 - learning_rate: 2.1464e-04
# Epoch 41/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0019 - mean_squared_error: 8.3650e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.4088e-04 - learning_rate: 2.0391e-04
# Epoch 42/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0019 - mean_squared_error: 8.1665e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.4735e-04 - learning_rate: 1.9371e-04
# Epoch 43/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - mean_squared_error: 8.4299e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.6044e-04 - learning_rate: 1.8403e-04
# Epoch 44/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0019 - mean_squared_error: 8.1005e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.3847e-04 - learning_rate: 1.7482e-04
# Epoch 45/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0019 - mean_squared_error: 8.1722e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.4291e-04 - learning_rate: 1.6608e-04
# Epoch 46/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - mean_squared_error: 8.2289e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.4834e-04 - learning_rate: 1.5778e-04
# Epoch 47/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0018 - mean_squared_error: 7.9940e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.2169e-04 - learning_rate: 1.4989e-04
# Epoch 48/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0151e-04 - val_loss: 0.0020 - val_mean_squared_error: 9.2937e-04 - learning_rate: 1.4240e-04
# Epoch 49/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019 - mean_squared_error: 8.5136e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.3124e-04 - learning_rate: 1.3528e-04
# Epoch 50/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.3146e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.3071e-04 - learning_rate: 1.2851e-04
# Epoch 51/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0326e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.2810e-04 - learning_rate: 1.2209e-04
# Epoch 52/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0617e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.3064e-04 - learning_rate: 1.1598e-04
# Epoch 53/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 7.9419e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.2009e-04 - learning_rate: 1.1018e-04
# Epoch 54/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.2887e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.2640e-04 - learning_rate: 1.0467e-04
# Epoch 55/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.2027e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.2931e-04 - learning_rate: 9.9440e-05
# Epoch 56/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0032e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1794e-04 - learning_rate: 9.4468e-05
# Epoch 57/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 7.9552e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.2590e-04 - learning_rate: 8.9745e-05
# Epoch 58/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0595e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.2684e-04 - learning_rate: 8.5258e-05
# Epoch 59/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 7.8437e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1585e-04 - learning_rate: 8.0995e-05
# Epoch 60/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.7200e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1299e-04 - learning_rate: 7.6945e-05
# Epoch 61/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 7.9968e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1735e-04 - learning_rate: 7.3098e-05
# Epoch 62/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0660e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.2879e-04 - learning_rate: 6.9443e-05
# Epoch 63/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 7.8901e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1969e-04 - learning_rate: 6.5971e-05
# Epoch 64/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0296e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1061e-04 - learning_rate: 6.2672e-05
# Epoch 65/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.8474e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1297e-04 - learning_rate: 5.9539e-05
# Epoch 66/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.6002e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.0475e-04 - learning_rate: 5.6562e-05
# Epoch 67/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.8912e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.0739e-04 - learning_rate: 5.3734e-05
# Epoch 68/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.8617e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.1149e-04 - learning_rate: 5.1047e-05
# Epoch 69/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5032e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.0389e-04 - learning_rate: 4.8495e-05
# Epoch 70/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.7473e-04 - val_loss: 0.0019 - val_mean_squared_error: 8.9986e-04 - learning_rate: 4.6070e-05
# Epoch 71/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.0252e-04 - val_loss: 0.0019 - val_mean_squared_error: 9.0687e-04 - learning_rate: 4.3766e-05
# Epoch 72/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018 - mean_squared_error: 8.1372e-04 - val_loss: 0.0018 - val_mean_squared_error: 9.0823e-04 - learning_rate: 4.1578e-05
# Epoch 73/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5906e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9149e-04 - learning_rate: 3.9499e-05
# Epoch 74/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5903e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9500e-04 - learning_rate: 3.7524e-05
# Epoch 75/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.6596e-04 - val_loss: 0.0018 - val_mean_squared_error: 9.0317e-04 - learning_rate: 3.5648e-05
# Epoch 76/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.6058e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9776e-04 - learning_rate: 3.3866e-05
# Epoch 77/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5330e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9664e-04 - learning_rate: 3.2172e-05
# Epoch 78/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.8244e-04 - val_loss: 0.0018 - val_mean_squared_error: 9.0113e-04 - learning_rate: 3.0564e-05
# Epoch 79/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.8462e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9934e-04 - learning_rate: 2.9035e-05
# Epoch 80/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.4862e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9654e-04 - learning_rate: 2.7584e-05
# Epoch 81/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5850e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9542e-04 - learning_rate: 2.6205e-05
# Epoch 82/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.6864e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9930e-04 - learning_rate: 2.4894e-05
# Epoch 83/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0017 - mean_squared_error: 7.5963e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9560e-04 - learning_rate: 2.3650e-05
# Epoch 84/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.7859e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9865e-04 - learning_rate: 2.2467e-05
# Epoch 85/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.7258e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9360e-04 - learning_rate: 2.1344e-05
# Epoch 86/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5430e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9499e-04 - learning_rate: 2.0277e-05
# Epoch 87/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.7898e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9394e-04 - learning_rate: 1.9263e-05
# Epoch 88/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.8696e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9413e-04 - learning_rate: 1.8300e-05
# Epoch 89/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5004e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9447e-04 - learning_rate: 1.7385e-05
# Epoch 90/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.6162e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9279e-04 - learning_rate: 1.6515e-05
# Epoch 91/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.2984e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9000e-04 - learning_rate: 1.5690e-05
# Epoch 92/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.6346e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.8911e-04 - learning_rate: 1.4905e-05
# Epoch 93/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.3579e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9189e-04 - learning_rate: 1.4160e-05
# Epoch 94/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.2866e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9016e-04 - learning_rate: 1.3452e-05
# Epoch 95/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.3831e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9320e-04 - learning_rate: 1.2779e-05
# Epoch 96/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.6493e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9167e-04 - learning_rate: 1.2140e-05
# Epoch 97/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.7244e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9144e-04 - learning_rate: 1.1533e-05
# Epoch 98/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.3977e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9296e-04 - learning_rate: 1.0957e-05
# Epoch 99/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.5652e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9444e-04 - learning_rate: 1.0409e-05
# Epoch 100/100
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mean_squared_error: 7.4348e-04 - val_loss: 0.0018 - val_mean_squared_error: 8.9069e-04 - learning_rate: 9.8884e-06

# %%
X_test_np = X_test.to_numpy()
X_train_np = X_train.to_numpy()

# %%
explainer = shap.GradientExplainer(rnn_simplificado, X_train_np)
shap_values = explainer(X_test_np)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_145
# Received: inputs=['Tensor(shape=(10268, 57))']
#   warnings.warn(msg)
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_145
# Received: inputs=['Tensor(shape=(50, 57))']
#   warnings.warn(msg)

# %%
print(f"Forma de shap_values: {np.shape(shap_values)}")
# Out:
# Forma de shap_values: (10268, 57, 1)

# %%
shap_values = shap_values[:, :, 0]

# %%
# Representamos todas las gráficas que hemos decidico representar de la librerís SHAP
shap_visualization(shap_values, X_test)
# Out:
# Ejecutando visualización 1: Bar Plot
# Ejecutando visualización 2: Waterfall Plot
# Error en la visualización 2: float() argument must be a string or a real number, not 'NoneType'
# Ejecutando visualización 3: Force Plot
# Error en la visualización 3: matplotlib = True is not yet supported for force plots with multiple samples!
# Ejecutando visualización 4: Beeswarm Plot
# Ejecutando visualización 5: Scatter Plots
# Error en la visualización 5: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Force Plot: Explicación visual de hasta 50 observaciones  
shap.force_plot(shap_values[:50])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 2
#       1 # Force Plot: Explicación visual de hasta 50 observaciones
# ----> 2 shap.force_plot(shap_values[:50])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_force.py:222, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     217         display_features = features[k, :]
#     219     instance = Instance(np.ones((1, len(feature_names))), display_features)
#     220     e = AdditiveExplanation(
#     221         base_value,
# --> 222         np.sum(shap_values[k, :]) + base_value,
#     223         shap_values[k, :],
#     224         None,
#     225         instance,
#     226         link,
#     227         Model(None, out_names),
#     228         DenseData(np.ones((1, len(feature_names))), list(feature_names))
#     229     )
#     230     exps.append(e)
#     232 return visualize(
#     233             exps,
#     234             plot_cmap=plot_cmap,
#    (...)
#     237             text_rotation=text_rotation
#     238         )
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'

# %% [markdown]
# ### 7.2. DeepExplainer

# %%
explainer = shap.DeepExplainer(dense, X_train)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test)
# Out:
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(41068, 57))']
#   warnings.warn(msg)
# C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(82136, 57))']
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# StagingError                              Traceback (most recent call last)
# Cell In[92], line 2
#       1 explainer = shap.DeepExplainer(dense, X_train)
# ----> 2 shap_values = explainer.shap_values(X_test)
#       3 shap.summary_plot(shap_values, X_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\__init__.py:159, in DeepExplainer.shap_values(self, X, ranked_outputs, output_rank_order, check_additivity)
#     115 def shap_values(self, X, ranked_outputs=None, output_rank_order='max', check_additivity=True):
#     116     """Return approximate SHAP values for the model applied to the data given by X.
#     117
#     118     Parameters
#    (...)
#     157
#     158     """
# --> 159     return self.explainer.shap_values(X, ranked_outputs, output_rank_order, check_additivity=check_additivity)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\deep_tf.py:329, in TFDeep.shap_values(self, X, ranked_outputs, output_rank_order, check_additivity)
#     327 # run attribution computation graph
#     328 feature_ind = model_output_ranks[j,i]
# --> 329 sample_phis = self.run(self.phi_symbolic(feature_ind), self.model_inputs, joint_input)
#     331 # assign the attributions to the right part of the output arrays
#     332 for t in range(len(X)):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\deep_tf.py:385, in TFDeep.run(self, out, model_inputs, X)
#     382         tf_execute.record_gradient = tf_backprop.record_gradient
#     384     return final_out
# --> 385 return self.execute_with_overridden_gradients(anon)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\deep_tf.py:420, in TFDeep.execute_with_overridden_gradients(self, f)
#     418 # define the computation graph for the attribution values using a custom gradient-like computation
#     419 try:
# --> 420     out = f()
#     421 finally:
#     422     # reinstate the backpropagatable check
#     423     if hasattr(tf_gradients_impl, "_IsBackpropagatable"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\deep_tf.py:378, in TFDeep.run.<locals>.anon()
#     376     v = tf.constant(data, dtype=self.model_inputs[i].dtype)
#     377     inputs.append(v)
# --> 378 final_out = out(inputs)
#     379 try:
#     380     tf_execute.record_gradient = tf_backprop._record_gradient
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:52, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
# ---> 52     raise e.ag_error_metadata.to_exception(e)
#      53   else:
#      54     raise
#
# StagingError: in user code:
#
#     File "C:\Users\Ismael Laso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_deep\deep_tf.py", line 269, in grad_graph  *
#         x_grad = tape.gradient(out, shap_rAnD)
#
#     LookupError: gradient registry has no entry for: shap_LeakyRelu
